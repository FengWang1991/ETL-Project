# %% [markdown]
# ### Initial setup
# * Libraries
# * Splinter Browser config

# %%
from bs4 import BeautifulSoup as bs
import pandas as pd
from splinter import Browser
import time
from tqdm import tqdm

# %%
# Windows
# executable_path = {"executable_path": "driver/chromedriver.exe"}
# browser = Browser("chrome", **executable_path)

# %%
# MAC
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

# %% [markdown]
# ### Initial Scraping
# This section of code scrapes data for the first page of the website. We noted the below:
# * The website shows all games by infinitely scrolling. We worked around this limitation by inspecting the HTML and finding the pagination div tag.
# * The first page has 50 rows of games and the consequent pages have 25 rows each.
# * However, the 50 rows in  Page 1 include the 25 rows from Page 2 i.e. Page 1 displays games of BOTH Page 1 and Page 2 combined.
# * The game_name, release_date and price are scraped from the 50 rows.
# * After scraping data from this page, we get the URL of Page 3 and use splinter to visit that page to continue scraping. Since Page 1 does not display page numbers, we also retrieve the last page number from Page 3's HTML to use in the for loop coming up.

# %%
# Visit the top sellers section on the Steam store using splinter
url="https://store.steampowered.com/search/?filter=topsellers"
browser.visit(url)
time.sleep(2)

# Get the html of the page and create a BeautifulSoup object
html = browser.html
soup = bs(html, 'html.parser')

# %%
# Create an empty list to append game info
top_sellers = []

# Start the result counter at zero
result_count = 0

# Get the parent div for each game row
results=soup.find_all("div",class_="responsive_search_name_combined")

# Loop over the rows and retrieve game data for the first 50 games
for result in results:
        
    # get the game title
    game_name = result.find("span",class_="title").text
        
    # get the release date
    release_date = result.find("div",class_="col search_released responsive_secondrow").text
        
    # get the price
    price = result.find("div",{"class":["col search_price responsive_secondrow","col search_price discounted responsive_secondrow"]}).text.strip()
        
    # add the key value pairs to python dictionary and append to the list
    top_sellers.append({"game_name": game_name,
                        "release_date": release_date,
                        "price": price })
    
    # increase counter once each result is processed
    result_count += 1

# %%
print(result_count)
# Out:
# 50

# %%
# After the initial scraping, find the pagination parent div on the main page and get the url for page 3 
pagination_div = soup.find('div', class_='search_pagination_right')
page_3_url = pagination_div.find_all('a')[1]['href']

# use splinter to proceed to the url
browser.visit(page_3_url)
time.sleep(2)       
    
# Create a new soup object out of the new html
newhtml = browser.html
newsoup = bs(newhtml, 'html.parser')

# get max page number from the pagination parent div
pagination_div = newsoup.find('div', class_='search_pagination_right')
max_pages = int(pagination_div.find_all('a')[-2].text)

# %% [markdown]
# ### Scraping
# * This section of code goes into a nested for loop for scraping data and will take about **9-11 minutes** to complete.
# * The scraped data is appended to the top_sellers list as a dictionary.
# * We find the next page url and use splinter to visit the url after each page loop.

# %%
page_num = 2

# Loop over each page to scrape until we hit the total number of pages (-2 as we have already scraped p1 & p2)
# tqdm is a progress bar module that tracks progress of a loop
for i in tqdm(range(0, max_pages-2)):
    
    # Create a new soup object out of the new html
    html = browser.html
    soup = bs(html, 'html.parser')  
    
    # get the parent div for each game row
    results=soup.find_all("div",class_="responsive_search_name_combined")

    # loop over each row (25 rows in each page) and retrieve game data
    for result in results:
        
        # get the game title
        game_name = result.find("span",class_="title").text
        
        # get the release date
        release_date = result.find("div",class_="col search_released responsive_secondrow").text
        
        # get the price
        price = result.find("div",{"class":["col search_price responsive_secondrow","col search_price discounted responsive_secondrow"]}).text.strip()
        
        # add the key value pairs to python dictionary and append to the list
        top_sellers.append({"game_name": game_name,
                            "release_date": release_date,
                            "price": price })
        
        # increase counter for results once each result is processed
        result_count += 1
        
    # increase counter for page number once each page is processed
    page_num +=1
        
    if page_num != max_pages:
        # After scraping the 25 results, find the pagination parent div
        pagination_div = soup.find('div', class_='search_pagination_right')
            
        # get the next page url from the second active page link with a class of 'pagebtn' 
        next_page_url = pagination_div.find_all('a', class_='pagebtn')[1]['href']
            
        # use splinter to proceed to the next page's url
        browser.visit(next_page_url)
        time.sleep(1)     
        
    else:
        print(f"Last page (p. {page_num}) reached - no more pages to scrape.")
        break

    
print(f'Scraping Complete! {result_count} top-selling games scraped.')
# Out:
# 100%|█████████▉| 224/225 [09:24<00:02,  2.41s/it]
# Last page (p. 227) reached - no more pages to scrape.
# Scraping Complete! 5675 top-selling games scraped.

# %%
print(max_pages)
# Out:
# 227

# %%
# Check list of results
for top in range(len(top_sellers)):
    print(f"{top}. {top_sellers[top]['game_name']} | {top_sellers[top]['release_date']} |\
          {top_sellers[top]['price']}")
# Out:
# 0. Fall Guys: Ultimate Knockout | 3 Aug, 2020 |          CDN$ 22.79
# 1. Fall Guys Collector's Edition |  |          CDN$ 33.99
# 2. Marvel's Avengers | 4 Sep, 2020 |          CDN$ 79.99
# 3. Factorio | 14 Aug, 2020 |          CDN$ 34.00
# 4. Microsoft Flight Simulator | 8/18/2020 |          CDN$ 79.99
# 5. Risk of Rain 2 | 11 Aug, 2020 |          CDN$ 24.99CDN$ 19.99
# 6. Fall Guys: Collectors Pack | 3 Aug, 2020 |          CDN$ 11.20
# 7. Among Us | 16 Nov, 2018 |          CDN$ 5.69
# 8. Horizon Zero Dawn™ Complete Edition | 7 Aug, 2020 |          CDN$ 59.99
# 9. Battle Brothers - Blazing Deserts | 13 Aug, 2020 |          CDN$ 17.49
# 10. Marvel's Avengers Deluxe Edition |  |          CDN$ 106.98
# 11. Endless Space® 2 Collection |  |          CDN$ 103.92CDN$ 24.62
# 12. Microsoft Flight Simulator | 8/18/2020 |          CDN$ 79.99
# 13. Battlefield ™ V | 11 Jun, 2020 |          CDN$ 64.99CDN$ 19.49
# 14. The Henry Stickmin Collection | 7 Aug, 2020 |          CDN$ 17.49
# 15. Halo: The Master Chief Collection | 3 Dec, 2019 |          CDN$ 49.99
# 16. Battle Brothers & All DLC |  |          CDN$ 72.26CDN$ 45.59
# 17. Battle Brothers | 24 Mar, 2017 |          CDN$ 32.99CDN$ 10.89
# 18. Grounded | 28 Jul, 2020 |          CDN$ 39.99
# 19. Dying Light Enhanced Edition |  |          CDN$ 59.99CDN$ 17.99
# 20. Sea of Thieves | 3 Jun, 2020 |          CDN$ 49.99
# 21. Grand Theft Auto V | 13 Apr, 2015 |          CDN$ 29.99CDN$ 14.99
# 22. Battlefield Bundle |  |          CDN$ 174.97CDN$ 40.17
# 23. Borderlands 3 | 13 Mar, 2020 |          CDN$ 79.99CDN$ 39.99
# 24. Borderlands 3 | 13 Mar, 2020 |          CDN$ 79.99CDN$ 39.99
# 25. Battlefield 4™ | 11 Jun, 2020 |          CDN$ 54.99CDN$ 13.74
# 26. Satisfactory | 8 Jun, 2020 |          CDN$ 33.99
# 27. Destiny 2: Upgrade Edition | 10 Dec, 2019 |          CDN$ 56.99
# 28. Red Dead Redemption 2 | 5 Dec, 2019 |          CDN$ 79.99
# 29. Crusader Kings III | 1 Sep, 2020 |          CDN$ 56.99
# 30. Cyberpunk 2077 | 18 Nov, 2020 |          CDN$ 79.99
# 31. Parkasaurus | 12 Aug, 2020 |          CDN$ 27.99CDN$ 22.39
# 32. Battlefield 1 ™ | 11 Jun, 2020 |          CDN$ 54.99CDN$ 20.34
# 33. STAR WARS™: The Old Republic™ - Cartel Coins | 21 Jul, 2020 |          CDN$ 4.99
# 34. STAR WARS™: The Old Republic™ - Cartel Coins | 21 Jul, 2020 |          CDN$ 4.99
# 35. STAR WARS™: The Old Republic™ - Cartel Coins | 21 Jul, 2020 |          CDN$ 4.99
# 36. STAR WARS™: The Old Republic™ - Cartel Coins | 21 Jul, 2020 |          CDN$ 4.99
# 37. STAR WARS™: The Old Republic™ - Cartel Coins | 21 Jul, 2020 |          CDN$ 4.99
# 38. Stardew Valley | 26 Feb, 2016 |          CDN$ 16.99CDN$ 13.59
# 39. NBA 2K21 | 4 Sep, 2020 |          CDN$ 79.99
# 40. Hollow Knight | 24 Feb, 2017 |          CDN$ 16.99CDN$ 8.49
# 41. RimWorld | 17 Oct, 2018 |          CDN$ 39.99CDN$ 35.99
# 42. Europa Universalis IV: Collection |  |          CDN$ 279.05
# 43. Football Manager 2020 | 19 Nov, 2019 |          CDN$ 59.99CDN$ 20.39
# 44. FINAL FANTASY XIV: Shadowbringers | 2 Jul, 2019 |          CDN$ 49.99
# 45. Battle Brothers - Beasts & Exploration | 29 Nov, 2018 |          CDN$ 11.49CDN$ 10.34
# 46. Battle Brothers - Warriors of the North | 9 May, 2019 |          CDN$ 10.29CDN$ 9.26
# 47. Monster Hunter World: Iceborne | 9 Jan, 2020 |          CDN$ 54.99
# 48. Raft | 23 May, 2018 |          CDN$ 21.99
# 49. Fall Guys - Fast Food Costume Pack | 4 Aug, 2020 |          CDN$ 5.69
# 50. Monster Hunter: World | 9 Aug, 2018 |          CDN$ 39.99
# 51. Rust | 8 Feb, 2018 |          CDN$ 45.49
# 52. PGA TOUR 2K21 | 21 Aug, 2020 |          CDN$ 79.99
# 53. Monster Hunter World: Iceborne Master Edition |  |          CDN$ 79.99
# 54. ANAREA Battle Royale | 14 Aug, 2020 |          CDN$ 20.49
# 55. Hell Let Loose | 6 Jun, 2019 |          CDN$ 33.99
# 56. Sid Meier's Civilization VI - New Frontier Pass | 21 May, 2020 |          CDN$ 53.49
# 57. Dead Cells | 6 Aug, 2018 |          CDN$ 29.99CDN$ 17.99
# 58. Fallout 76: Atoms | 14 Apr, 2020 |          CDN$ 6.49
# 59. Fallout 76: Atoms | 14 Apr, 2020 |          CDN$ 6.49
# 60. Fallout 76: Atoms | 14 Apr, 2020 |          CDN$ 6.49
# 61. Fallout 76: Atoms | 14 Apr, 2020 |          CDN$ 6.49
# 62. RimWorld - Royalty | 24 Feb, 2020 |          CDN$ 22.79
# 63. FINAL FANTASY XIV Online | 18 Feb, 2014 |          CDN$ 24.99
# 64. Grand Theft Auto V: Premium Online Edition |  |          CDN$ 39.98CDN$ 15.98
# 65. Popup Dungeon | 12 Aug, 2020 |          CDN$ 28.99CDN$ 26.09
# 66. Mount & Blade II: Bannerlord | 30 Mar, 2020 |          CDN$ 64.99
# 67. Slay the Spire | 23 Jan, 2019 |          CDN$ 28.99CDN$ 14.49
# 68. Age of Empires II: Definitive Edition | 14 Nov, 2019 |          CDN$ 21.99
# 69. Endless Space® 2 - Penumbra | 24 Jan, 2019 |          CDN$ 15.99CDN$ 5.43
# 70. Beat Saber | 21 May, 2019 |          CDN$ 33.99
# 71. Othercide | 27 Jul, 2020 |          CDN$ 44.99
# 72. Crusader Kings III | 1 Sep, 2020 |          CDN$ 56.99
# 73. LEGO® DC Super-Villains | 16 Oct, 2018 |          CDN$ 59.99CDN$ 14.99
# 74. Persona 4 Golden | 13 Jun, 2020 |          CDN$ 23.99
# 75. PLAYERUNKNOWN'S BATTLEGROUNDS | 21 Dec, 2017 |          CDN$ 36.99
# 76. Tabletop Simulator | 5 Jun, 2015 |          CDN$ 21.99
# 77. Edge Of Eternity | 5 Dec, 2018 |          CDN$ 22.79CDN$ 15.95
# 78. Dead by Daylight | 14 Jun, 2016 |          CDN$ 21.99
# 79. Destiny 2: Beyond Light Deluxe Edition | 10 Nov, 2020 |          CDN$ 84.99
# 80. Wallpaper Engine | 16 Nov, 2018 |          CDN$ 4.99
# 81. Bundle: South Park™ : The Stick of Truth™ + The Fractured but Whole™ |  |          CDN$ 95.83
# 82. Dying Light Ultimate Collection |  |          CDN$ 130.75CDN$ 59.54
# 83. Tom Clancy's Rainbow Six® Siege | 1 Dec, 2015 |          CDN$ 29.99
# 84. Dead Cells: The Bad Seed Bundle |  |          CDN$ 35.68CDN$ 21.31
# 85. Call of Duty®: Black Ops III | 6 Nov, 2015 |          CDN$ 79.99
# 86. MORDHAU | 29 Apr, 2019 |          CDN$ 33.99
# 87. Dying Light | 27 Jan, 2015 |          CDN$ 49.99CDN$ 16.99
# 88. STAR WARS™: The Old Republic™  - Subscriptions | 21 Jul, 2020 |          CDN$ 19.99
# 89. STAR WARS™: The Old Republic™  - Subscriptions | 21 Jul, 2020 |          CDN$ 19.99
# 90. Temtem | 21 Jan, 2020 |          CDN$ 45.49
# 91. Garry's Mod | 29 Nov, 2006 |          CDN$ 10.99
# 92. Fallout 76 | 14 Apr, 2020 |          CDN$ 54.99
# 93. Endless Space® 2 - Supremacy | 2 Aug, 2018 |          CDN$ 15.99CDN$ 3.99
# 94. Sekiro™: Shadows Die Twice | 22 Mar, 2019 |          CDN$ 79.99
# 95. Pummel Party | 20 Sep, 2018 |          CDN$ 17.49
# 96. Dreamscaper | 14 Aug, 2020 |          CDN$ 24.89CDN$ 18.66
# 97. UnderMine | 6 Aug, 2020 |          CDN$ 22.79
# 98. Deep Rock Galactic | 13 May, 2020 |          CDN$ 34.99
# 99. Wasteland 3 | August 28, 2020 |          CDN$ 79.99
# 100. PAYDAY 2: Legacy Collection |  |          CDN$ 89.23CDN$ 14.92
# 101. LEGO® Marvel Super Heroes 2 | 14 Nov, 2017 |          CDN$ 29.99CDN$ 7.49
# 102. West of Loathing | 10 Aug, 2017 |          CDN$ 14.99CDN$ 8.69
# 103. The Elder Scrolls V: Skyrim Special Edition | 27 Oct, 2016 |          CDN$ 49.99
# 104. Crossout - The Inventor Pack | 21 Sep, 2017 |          CDN$ 85.99
# 105. Grand Theft Auto V - Criminal Enterprise Starter Pack | 14 Dec, 2017 |          CDN$ 9.99
# 106. State of Decay 2: Juggernaut Edition | 13 Mar, 2020 |          CDN$ 39.99
# 107. Assassin's Creed® Odyssey | 5 Oct, 2018 |          CDN$ 79.99
# 108. DARK SOULS III Deluxe Edition | 11 Apr, 2016 |          CDN$ 93.99
# 109. Rocket League® | 7 Jul, 2015 |          CDN$ 21.99
# 110. CS:GO Prime Status Upgrade | 21 Aug, 2012 |          CDN$ 19.99
# 111. EA SPORTS™ FIFA 21 | 9 Oct, 2020 |          CDN$ 79.99
# 112. Kill It With Fire | 13 Aug, 2020 |          CDN$ 17.49CDN$ 15.74
# 113. Sailaway - The Sailing Simulator | 27 Feb, 2018 |          CDN$ 51.49
# 114. Total War: MEDIEVAL II - Definitive Edition | 27 Nov, 2007 |          CDN$ 29.99
# 115. ARK: Genesis Season Pass | 8 Aug, 2019 |          CDN$ 39.99
# 116. The Elder Scrolls® Online | 22 May, 2017 |          CDN$ 24.99CDN$ 12.49
# 117. Crossout - Arsonist Pack | 23 Jan, 2018 |          CDN$ 79.99
# 118. Torchlight III | 13 Jun, 2020 |          CDN$ 33.99
# 119. Fantasy Grounds Ultimate License |  |          CDN$ 163.91
# 120. Squad | 15 Dec, 2015 |          CDN$ 49.99
# 121. Endless Space® 2 - Vaulters | 25 Jan, 2018 |          CDN$ 11.99CDN$ 2.99
# 122. Last Epoch | 30 Apr, 2019 |          CDN$ 39.99
# 123. Subnautica: Below Zero | 30 Jan, 2019 |          CDN$ 22.79
# 124. Crossout - Iron Shield Pack | 19 Apr, 2018 |          CDN$ 75.99
# 125. Terraria | 16 May, 2011 |          CDN$ 10.99
# 126. Holdfast: Nations At War | 5 Mar, 2020 |          CDN$ 21.99
# 127. NBA 2K21 | 4 Sep, 2020 |          CDN$ 79.99
# 128. Wolfenstein Alt History Collection |  |          CDN$ 104.36
# 129. CODE VEIN | 26 Sep, 2019 |          CDN$ 79.99
# 130. Zero Hour | 12 Aug, 2020 |          CDN$ 13.49CDN$ 12.14
# 131. Stellaris: Federations | 17 Mar, 2020 |          CDN$ 22.79
# 132. Injustice™ 2 | 14 Nov, 2017 |          CDN$ 69.99
# 133. Destroy All Humans! | 28 Jul, 2020 |          CDN$ 29.99
# 134. Phantasy Star Online 2 - SONIC Collaboration Pack | 5 Aug, 2020 |          CDN$ 79.99
# 135. Crossout - Arachnophobia Pack | 30 Nov, 2017 |          CDN$ 69.99
# 136. Valve Index Headset + Controllers | 28 Jun, 2019 |          CDN$ 989.00
# 137. Capcom Beat 'Em Up Bundle | 10 Oct, 2018 |          CDN$ 26.99CDN$ 13.49
# 138. XCOM® 2 | 5 Feb, 2016 |          CDN$ 79.99
# 139. F1® 2019 | 27 Jun, 2019 |          CDN$ 68.99CDN$ 17.24
# 140. Expansion - Hearts of Iron IV: La Résistance | 25 Feb, 2020 |          CDN$ 22.79
# 141. Elder Scrolls Summer Bundle |  |          CDN$ 85.47
# 142. Pathfinder: Kingmaker - Imperial Edition Bundle |  |          CDN$ 68.49
# 143. NieR:Automata™ | 17 Mar, 2017 |          CDN$ 53.50
# 144. Eastern Exorcist | 14 Aug, 2020 |          CDN$ 19.49CDN$ 15.59
# 145. PC Building Simulator - Maxed Out Edition |  |          CDN$ 59.29
# 146. CARRION | 23 Jul, 2020 |          CDN$ 22.79
# 147. Oblivion Game of the Year Deluxe | 16 Jun, 2009 |          CDN$ 24.99
# 148. The Sims™ 4 | 18 Jun, 2020 |          CDN$ 39.99
# 149. Total War™: ROME II - Emperor Edition | 3 Sep, 2013 |          CDN$ 71.99
# 150. DCS: Persian Gulf | 1 Jun, 2018 |          CDN$ 70.99
# 151. Crossout - Spectral Hunter Pack | 22 May, 2018 |          CDN$ 63.99
# 152. KovaaK 2.0 | 3 Apr, 2018 |          CDN$ 11.49
# 153. WWE 2K19 | 9 Oct, 2018 |          CDN$ 79.99
# 154. GOD EATER 3 | 7 Feb, 2019 |          CDN$ 79.99
# 155. Elite Dangerous: Commander Deluxe Edition |  |          CDN$ 79.99
# 156. FAIRY TAIL | 29 Jul, 2020 |          CDN$ 68.99
# 157. BeamNG.drive | 29 May, 2015 |          CDN$ 28.99
# 158. Grand Theft Auto V: Premium Online Edition & Megalodon Shark Card Bundle |  |          CDN$ 139.97CDN$ 58.27
# 159. American Truck Simulator | 2 Feb, 2016 |          CDN$ 25.99
# 160. Subnautica | 23 Jan, 2018 |          CDN$ 28.99
# 161. Pavlov VR | 27 Feb, 2017 |          CDN$ 28.99
# 162. Kenshi | 6 Dec, 2018 |          CDN$ 33.99
# 163. GTFO | 9 Dec, 2019 |          CDN$ 39.99
# 164. Pathfinder: Kingmaker - Enhanced Edition | 25 Sep, 2018 |          CDN$ 33.99
# 165. Foundation | 1 Feb, 2019 |          CDN$ 33.99
# 166. Age of Empires II (2013) | 9 Apr, 2013 |          CDN$ 21.99
# 167. Cities: Skylines - City Startup Bundle |  |          CDN$ 73.76
# 168. Aliens Colonial Marines Collection |  |          CDN$ 33.99
# 169. LEGO® The Lord of the Rings™ | 27 Nov, 2012 |          CDN$ 19.99CDN$ 4.99
# 170. Hades | 10 Dec, 2019 |          CDN$ 28.99
# 171. Hatsune Miku VR Complete |  |          CDN$ 62.51
# 172. Half-Life: Alyx | 23 Mar, 2020 |          CDN$ 68.99
# 173. Tales of Vesperia: Definitive Edition | 10 Jan, 2019 |          CDN$ 64.99
# 174. DEATH STRANDING | 14 Jul, 2020 |          CDN$ 79.99
# 175. LEGO Movie 2 - Videogame & LEGO Worlds Bundle |  |          CDN$ 69.98CDN$ 16.98
# 176. Europa Universalis IV: Emperor | 9 Jun, 2020 |          CDN$ 22.79
# 177. F1® 2020 | 9 Jul, 2020 |          CDN$ 68.99
# 178. Rising Star 2 | 12 Aug, 2020 |          CDN$ 33.99
# 179. ARK: Survival Evolved | 29 Aug, 2017 |          CDN$ 59.99
# 180. Space Haven | 21 May, 2020 |          CDN$ 26.99CDN$ 24.29
# 181. GTA V: Great White Shark Cash Card (Placeholder DLC) |  |          CDN$ 19.99
# 182. Digimon Story Cyber Sleuth: Complete Edition | 17 Oct, 2019 |          CDN$ 64.99
# 183. Remnant: From the Ashes | 20 Aug, 2019 |          CDN$ 45.49
# 184. Borderlands 3: Season Pass | 13 Mar, 2020 |          CDN$ 66.99CDN$ 53.59
# 185. Gunfire Reborn | 22 May, 2020 |          CDN$ 13.49
# 186. GOD EATER 2 Rage Burst | 29 Aug, 2016 |          CDN$ 69.99
# 187. Return of the Obra Dinn | 18 Oct, 2018 |          CDN$ 22.79CDN$ 18.23
# 188. Foxhole | 27 Jul, 2017 |          CDN$ 21.99CDN$ 12.09
# 189. Littlewood | 4 Aug, 2020 |          CDN$ 17.49
# 190. Yes, Your Grace | 6 Mar, 2020 |          CDN$ 22.79CDN$ 18.23
# 191. Dying Light - Hellraid | 13 Aug, 2020 |          CDN$ 13.49
# 192. Cities: Skylines | 10 Mar, 2015 |          CDN$ 32.99
# 193. House Flipper | 17 May, 2018 |          CDN$ 22.79
# 194. Stranded Deep | 23 Jan, 2015 |          CDN$ 16.99
# 195. The Forest | 30 Apr, 2018 |          CDN$ 22.79
# 196. Endless Space® 2 - Starter Pack |  |          CDN$ 59.95CDN$ 13.45
# 197. DARK SOULS™ III | 11 Apr, 2016 |          CDN$ 66.49
# 198. Command & Conquer™ Remastered Collection | 5 Jun, 2020 |          CDN$ 26.99
# 199. LEGO® Star Wars™ - The Complete Saga | 12 Nov, 2009 |          CDN$ 22.79
# 200. NEKOPARA complete edition |  |          CDN$ 32.63
# 201. Microsoft Flight Simulator | 8/18/2020 |          CDN$ 79.99
# 202. Dragon Age™ Inquisition | 4 Jun, 2020 |          CDN$ 54.99
# 203. Titanfall® 2 | 18 Jun, 2020 |          CDN$ 39.99
# 204. GTA V: Megalodon Shark Cash Card |  |          CDN$ 99.99CDN$ 84.99
# 205. Fallout 1st | 14 Apr, 2020 |          CDN$ 17.99
# 206. Fallout 1st | 14 Apr, 2020 |          CDN$ 17.99
# 207. Fallout New Vegas Ultimate | 7 Feb, 2012 |          CDN$ 21.99
# 208. LEGO® Marvel Collection |  |          CDN$ 145.86CDN$ 44.54
# 209. Green Hell | 5 Sep, 2019 |          CDN$ 28.99
# 210. There Is No Game : Wrong Dimension | 6 Aug, 2020 |          CDN$ 14.49
# 211. theHunter: Call of the Wild™ | 16 Feb, 2017 |          CDN$ 25.49
# 212. Call of Duty®: Black Ops | 9 Nov, 2010 |          CDN$ 43.99
# 213. Post Scriptum | 9 Aug, 2018 |          CDN$ 38.00
# 214. Hellpoint | 30 Jul, 2020 |          CDN$ 39.99
# 215. Valve Index VR Kit | 28 Jun, 2019 |          CDN$ 1,319.00
# 216. Stormworks: Build and Rescue | 28 Feb, 2018 |          CDN$ 22.79
# 217. FINAL FANTASY XV WINDOWS EDITION | 6 Mar, 2018 |          CDN$ 45.99
# 218. Total War: WARHAMMER II - The Warden & The Paunch | 21 May, 2020 |          CDN$ 10.49
# 219. Planet Zoo | 5 Nov, 2019 |          CDN$ 51.49
# 220. LEGO® Harry Potter: Years 1-4 | 25 Jun, 2010 |          CDN$ 19.99CDN$ 4.99
# 221. LEGO® Harry Potter: Years 1-4 | 25 Jun, 2010 |          CDN$ 19.99CDN$ 4.99
# 222. Frostpunk: Game of the Year Edition |  |          CDN$ 73.66CDN$ 52.48
# 223. The Legend of Heroes: Trails of Cold Steel II | 14 Feb, 2018 |          CDN$ 49.99
# 224. eFootball  PES 2020 | 10 Sep, 2019 |          CDN$ 39.59CDN$ 19.79
# 225. For The King | 19 Apr, 2018 |          CDN$ 22.79CDN$ 9.11
# 226. PC Building Simulator | 29 Jan, 2019 |          CDN$ 22.79
# 227. Total War: WARHAMMER II - Curse of the Vampire Coast | 8 Nov, 2018 |          CDN$ 21.99
# 228. PAYDAY 2 | 13 Aug, 2013 |          CDN$ 11.49CDN$ 5.74
# 229. GUILTY GEAR Xrd -REVELATOR- | 14 Dec, 2016 |          CDN$ 32.99
# 230. No Man's Sky | 12 Aug, 2016 |          CDN$ 66.49
# 231. Scrap Mechanic | 20 Jan, 2016 |          CDN$ 21.99
# 232. The Legend of Heroes: Trails of Cold Steel | 2 Aug, 2017 |          CDN$ 49.99
# 233. DARK SOULS™ II: Scholar of the First Sin | 1 Apr, 2015 |          CDN$ 49.99
# 234. Yakuza 0 | 1 Aug, 2018 |          CDN$ 29.99
# 235. Car Mechanic Simulator 2018 | 28 Jul, 2017 |          CDN$ 21.99
# 236. SCUM | 29 Aug, 2018 |          CDN$ 33.99
# 237. Rocket Arena | 13 Jul, 2020 |          CDN$ 39.99CDN$ 6.79
# 238. Borderlands 2 Game of the Year | 8 Oct, 2013 |          CDN$ 43.99CDN$ 9.67
# 239. Frostpunk: The Last Autumn | 21 Jan, 2020 |          CDN$ 19.49
# 240. Farming Simulator 19 | 19 Nov, 2018 |          CDN$ 32.99
# 241. Banners of Ruin | 30 Jul, 2020 |          CDN$ 22.79
# 242. Gears 5 | 9 Sep, 2019 |          CDN$ 49.99
# 243. Destiny 2: Shadowkeep | 1 Oct, 2019 |          CDN$ 39.99
# 244. Flashing Lights - Police, Firefighting, Emergency Services Simulator | 7 Jun, 2018 |          CDN$ 22.79
# 245. American Truck Simulator - Idaho | 16 Jul, 2020 |          CDN$ 12.99
# 246. One Step From Eden | 26 Mar, 2020 |          CDN$ 22.79
# 247. Pacific Northwest |  |          CDN$ 50.90
# 248. Warhammer: Vermintide 2 | 8 Mar, 2018 |          CDN$ 33.99
# 249. Dungeon Defenders: Awakened | 28 May, 2020 |          CDN$ 33.99
# 250. The Jackbox Party Pack 4 | 19 Oct, 2017 |          CDN$ 27.99
# 251. Left 4 Dead 2 | 17 Nov, 2009 |          CDN$ 11.49
# 252. Company of Heroes 2 Master Collection |  |          CDN$ 39.72
# 253. BioShock™ Remastered | 15 Sep, 2016 |          CDN$ 21.99
# 254. Warhammer 40,000: Dawn of War III | 27 Apr, 2017 |          CDN$ 47.99
# 255. Deus Ex: Mankind Divided - Digital Deluxe Edition |  |          CDN$ 49.98
# 256. DOOM Eternal | 20 Mar, 2020 |          CDN$ 79.99
# 257. Undertale | 15 Sep, 2015 |          CDN$ 10.99
# 258. Oxygen Not Included | 30 Jul, 2019 |          CDN$ 27.99
# 259. Panzer Corps 2 | 19 Mar, 2020 |          CDN$ 45.49
# 260. PAYDAY 2: Breakfast in Tijuana Bundle |  |          CDN$ 14.77CDN$ 10.24
# 261. Planet Zoo: Premium Edition |  |          CDN$ 74.78
# 262. ELEX | 17 Oct, 2017 |          CDN$ 54.99CDN$ 18.14
# 263. Hollow Knight & Soundtracks |  |          CDN$ 33.67CDN$ 13.45
# 264. Survivor Pass: Payback | 21 Jul, 2020 |          CDN$ 12.99
# 265. Castle Crashers® | 26 Sep, 2012 |          CDN$ 16.99
# 266. LEGO® The Hobbit™ | 10 Apr, 2014 |          CDN$ 19.99CDN$ 4.99
# 267. GTA V: Megalodon Shark Cash Card |  |          CDN$ 99.99CDN$ 84.99
# 268. The LEGO Movie 2 Videogame | 26 Feb, 2019 |          CDN$ 39.99CDN$ 7.99
# 269. A Hat in Time | 5 Oct, 2017 |          CDN$ 32.99
# 270. Elite Dangerous | 2 Apr, 2015 |          CDN$ 39.99
# 271. Blade and Sorcery | 11 Dec, 2018 |          CDN$ 22.79
# 272. Frostpunk: Season Pass |  |          CDN$ 39.67CDN$ 24.99
# 273. Endless Space® 2 - Celestial Worlds | 15 Nov, 2018 |          CDN$ 3.99CDN$ 0.99
# 274. Warriors of the Nile | 7 Aug, 2020 |          CDN$ 14.49
# 275. Dead Cells: The Bad Seed | 11 Feb, 2020 |          CDN$ 5.69
# 276. West of Loathing: Reckonin' at Gun Manor | 8 Feb, 2019 |          CDN$ 6.99CDN$ 4.05
# 277. Monster Train | 21 May, 2020 |          CDN$ 28.99
# 278. PGA TOUR 2K21 | 21 Aug, 2020 |          CDN$ 79.99
# 279. Eco | 6 Feb, 2018 |          CDN$ 33.99
# 280. Ultimate Epic Battle Simulator | 1 Jun, 2017 |          CDN$ 17.49
# 281. Sid Meier's Civilization® VI: Gathering Storm | 14 Feb, 2019 |          CDN$ 53.49
# 282. LEGO® Harry Potter: Years 5-7 | 5 Jan, 2012 |          CDN$ 19.99CDN$ 4.99
# 283. Endless Space® 2 - Untold Tales | 12 Mar, 2018 |          CDN$ 3.99CDN$ 0.99
# 284. Parkitect | 29 Nov, 2018 |          CDN$ 33.99
# 285. Blazing Deserts Supporter Edition |  |          CDN$ 28.98
# 286. LEGO® The Incredibles | 15 Jun, 2018 |          CDN$ 59.99CDN$ 14.99
# 287. The Jackbox Party Pack 6 | 17 Oct, 2019 |          CDN$ 33.99
# 288. Crysis® Maximum Edition |  |          CDN$ 39.99
# 289. Total War: SHOGUN 2 | 15 Mar, 2011 |          CDN$ 35.99
# 290. Skully | 4 Aug, 2020 |          CDN$ 39.99
# 291. DayZ Livonia | 3 Dec, 2019 |          CDN$ 18.99
# 292. Divinity: Original Sin 2 - Definitive Edition | 14 Sep, 2017 |          CDN$ 54.99
# 293. Deep Rock Galactic: Dwarven Legacy |  |          CDN$ 65.55
# 294. Black Desert Online | 24 May, 2017 |          CDN$ 12.99
# 295. Grand Theft Auto V: Premium Online Edition & Great White Shark Card Bundle |  |          CDN$ 59.97CDN$ 28.77
# 296. Kingdom Under Fire Classics |  |          CDN$ 39.98CDN$ 19.48
# 297. Deus Ex: Mankind Divided | 23 Aug, 2016 |          CDN$ 34.99
# 298. Skater XL - The Ultimate Skateboarding Game | 28 Jul, 2020 |          CDN$ 45.49
# 299. Grand Theft Auto IV: The Complete Edition | 2 Dec, 2008 |          CDN$ 29.99
# 300. 3DMark | 12 Feb, 2013 |          CDN$ 33.99
# 301. Sid Meier's Civilization® V | 21 Sep, 2010 |          CDN$ 32.99
# 302. Victoria Collection |  |          CDN$ 83.48CDN$ 37.50
# 303. Baba Is You | 13 Mar, 2019 |          CDN$ 17.49
# 304. Beat Blast | 14 Aug, 2020 |          CDN$ 15.49CDN$ 13.16
# 305. Automation - The Car Company Tycoon Game | 12 Mar, 2015 |          CDN$ 33.99
# 306. DOOM | 13 May, 2016 |          CDN$ 24.99
# 307. Cooking Simulator Complete Bundle! |  |          CDN$ 44.27CDN$ 29.12
# 308. Hellblade: Senua's Sacrifice | 7 Aug, 2017 |          CDN$ 32.99
# 309. Avorion | 9 Mar, 2020 |          CDN$ 28.99
# 310. Grim Dawn Definitive Edition |  |          CDN$ 62.45
# 311. Tales Of Glory | 30 May, 2020 |          CDN$ 32.99
# 312. LEGO Batman Trilogy | 11 Nov, 2014 |          CDN$ 49.99CDN$ 9.99
# 313. Iratus: Lord of the Dead | 23 Apr, 2020 |          CDN$ 33.99
# 314. Slime Rancher | 1 Aug, 2017 |          CDN$ 21.99
# 315. 7 Days to Die | 13 Dec, 2013 |          CDN$ 27.99
# 316. Total War: WARHAMMER - Norsca | 10 Aug, 2017 |          CDN$ 11.99
# 317. Total War: WARHAMMER II | 28 Sep, 2017 |          CDN$ 71.99
# 318. Space Engineers Ultimate Edition |  |          CDN$ 46.76
# 319. Fable Anniversary | 12 Sep, 2014 |          CDN$ 38.69
# 320. 古剑奇谭三(Gujian3) | 14 Dec, 2018 |          CDN$ 33.99
# 321. The Feud: Wild West Tactics | 22 Jul, 2020 |          CDN$ 32.99
# 322. BlazBlue Collection |  |          CDN$ 109.96CDN$ 16.80
# 323. Endless Space® 2 - Harmonic Memories | 15 Nov, 2018 |          CDN$ 3.99CDN$ 0.99
# 324. Among Us - Mini Crewmate Bundle | 7 Jun, 2019 |          CDN$ 3.39
# 325. Operencia: The Stolen Sun | 31 Mar, 2020 |          CDN$ 33.99
# 326. NEKOPARA OVA | 21 Dec, 2017 |          CDN$ 33.99
# 327. Ultimate General: Civil War | 14 Jul, 2017 |          CDN$ 32.99
# 328. Void Bastards | 28 May, 2019 |          CDN$ 33.99
# 329. Company of Crime | 8 Aug, 2020 |          CDN$ 33.99
# 330. Hellsplit: Arena | 9 Sep, 2019 |          CDN$ 28.99
# 331. DiRT Rally 2.0 | 25 Feb, 2019 |          CDN$ 45.49CDN$ 11.37
# 332. Borderlands GOTY Enhanced | 26 Oct, 2009 |          CDN$ 32.99CDN$ 10.88
# 333. Beyond: Two Souls | 18 Jun, 2020 |          CDN$ 21.99
# 334. Rising Storm 2: Vietnam | 30 May, 2017 |          CDN$ 27.99
# 335. METAL GEAR SOLID V: THE PHANTOM PAIN | 1 Sep, 2015 |          CDN$ 29.99
# 336. Call of Duty: World at War | 18 Nov, 2008 |          CDN$ 21.99
# 337. Battlefield 4™ Ultimate Shortcut Bundle | 11 Jun, 2020 |          CDN$ 39.99CDN$ 7.99
# 338. Frostpunk | 24 Apr, 2018 |          CDN$ 33.99
# 339. Total War: THREE KINGDOMS | 23 May, 2019 |          CDN$ 71.99
# 340. Microsoft Flight Simulator X: Steam Edition | 18 Dec, 2014 |          CDN$ 27.99
# 341. ASTRONEER | 6 Feb, 2019 |          CDN$ 34.99
# 342. Cities: Skylines - Sunset Harbor | 26 Mar, 2020 |          CDN$ 17.49
# 343. Gang Beasts | 12 Dec, 2017 |          CDN$ 21.99
# 344. Fallout 4 - Creation Club | 28 Aug, 2017 |          CDN$ 9.99
# 345. Bad North: Jotunn Edition | 16 Nov, 2018 |          CDN$ 17.49CDN$ 8.74
# 346. Overcooked! 2 | 7 Aug, 2018 |          CDN$ 28.99
# 347. Hunt: Showdown | 27 Aug, 2019 |          CDN$ 54.00
# 348. Rocksmith™ | 16 Oct, 2012 |          CDN$ 29.99
# 349. For Honor Y4S2 Battle Bundle | 11 Jun, 2020 |          CDN$ 34.99
# 350. Empyrion - Galactic Survival | 5 Aug, 2020 |          CDN$ 21.99
# 351. The Sims 3: Supernatural | 20 Nov, 2012 |          CDN$ 26.99
# 352. TT Isle of Man Ride on the Edge | 27 Mar, 2018 |          CDN$ 45.49CDN$ 13.64
# 353. The Jackbox Party Pack 3 | 17 Oct, 2016 |          CDN$ 27.99
# 354. Franchise Hockey Manager 6 | 11 Oct, 2019 |          CDN$ 22.79
# 355. Vampire: The Masquerade - Coteries of New York | 11 Dec, 2019 |          CDN$ 22.79CDN$ 14.81
# 356. Godhood | 11 Aug, 2020 |          CDN$ 33.99CDN$ 27.19
# 357. Expansion - Europa Universalis IV: Common Sense | 9 Jun, 2015 |          CDN$ 16.99
# 358. SUPERHOT VR | 25 May, 2017 |          CDN$ 27.99
# 359. Human: Fall Flat | 22 Jul, 2016 |          CDN$ 16.99
# 360. BlazBlue Centralfiction | 26 Apr, 2017 |          CDN$ 43.99CDN$ 8.79
# 361. Agrou | 25 Jul, 2020 |          CDN$ 13.49
# 362. Rising Storm 2: Vietnam - Digital Deluxe Edition | 30 May, 2017 |          CDN$ 32.99
# 363. Operator's Pack |  |          CDN$ 123.10CDN$ 44.83
# 364. Total War: WARHAMMER II - Rise of the Tomb Kings | 24 Jan, 2018 |          CDN$ 21.99
# 365. Total War: WARHAMMER II - The Prophet & The Warlock | 17 Apr, 2019 |          CDN$ 10.49
# 366. Ostriv | 19 Mar, 2020 |          CDN$ 28.99
# 367. DayZ | 13 Dec, 2018 |          CDN$ 59.99
# 368. Northgard: The Viking Age Edition |  |          CDN$ 56.19
# 369. Cooking Simulator - Cakes and Cookies | 11 Jun, 2020 |          CDN$ 13.49CDN$ 11.46
# 370. 5D Chess With Multiverse Time Travel | 22 Jul, 2020 |          CDN$ 13.49
# 371. JUMP FORCE - Characters Pass 2 | 21 May, 2020 |          CDN$ 25.99
# 372. Stick Fight: The Game | 28 Sep, 2017 |          CDN$ 5.49
# 373. Neon Abyss | 14 Jul, 2020 |          CDN$ 22.79
# 374. Assetto Corsa Competizione - GT4 Pack | 15 Jul, 2020 |          CDN$ 27.99
# 375. Warhammer: Vermintide 2 - Winds of Magic | 13 Aug, 2019 |          CDN$ 22.79
# 376. Ori and the Blind Forest: Definitive Edition | 27 Apr, 2016 |          CDN$ 22.09
# 377. Total War: THREE KINGDOMS - A World Betrayed | 19 Mar, 2020 |          CDN$ 11.99
# 378. Baldur's Gate II: Enhanced Edition | 15 Nov, 2013 |          CDN$ 21.99
# 379. Totally Accurate Battle Simulator | 1 Apr, 2019 |          CDN$ 17.49
# 380. Cities: Skylines - Industries | 23 Oct, 2018 |          CDN$ 17.49
# 381. Visage | 2 Oct, 2018 |          CDN$ 24.99
# 382. Forager | 18 Apr, 2019 |          CDN$ 22.79
# 383. Endless Space® 2 - Lost Symphony | 12 Mar, 2018 |          CDN$ 3.99CDN$ 0.99
# 384. Brawlhalla - All Legends (Current and Future) | 26 Aug, 2015 |          CDN$ 21.99
# 385. Fell Seal: Arbiter's Mark | 30 Apr, 2019 |          CDN$ 33.99CDN$ 11.55
# 386. Griftlands | 14 Jun, 2020 |          CDN$ 22.79
# 387. Fault | 17 Jul, 2020 |          CDN$ 22.79
# 388. STAR WARS™ Battlefront™ II | 11 Jun, 2020 |          CDN$ 51.99
# 389. Metamorphosis | 12 Aug, 2020 |          CDN$ 28.99CDN$ 26.09
# 390. Endless Space® 2 - Awakening | 12 Sep, 2019 |          CDN$ 15.99CDN$ 7.99
# 391. Detroit: Become Human | 18 Jun, 2020 |          CDN$ 43.99
# 392. The Sims™ 3 Late Night | 27 Jan, 2011 |          CDN$ 26.99
# 393. PAYDAY 2: Breakfast in Tijuana Heist | 30 Jun, 2020 |          CDN$ 7.99CDN$ 7.19
# 394. Tannenberg | 16 Nov, 2017 |          CDN$ 24.99
# 395. SimCity™ 4 Deluxe Edition | 20 Jul, 2010 |          CDN$ 26.99
# 396. PixelFade Visual Novels |  |          CDN$ 58.69
# 397. Rivals of Aether | 28 Mar, 2017 |          CDN$ 16.99
# 398. Master of Orion | 25 Aug, 2016 |          CDN$ 28.99
# 399. Colony Survival | 16 Jun, 2017 |          CDN$ 22.79
# 400. Session: Skateboarding Sim Game | 17 Sep, 2019 |          CDN$ 22.79
# 401. Monster Hunter World: Iceborne Master Edition Digital Deluxe |  |          CDN$ 99.99
# 402. Halo 3 | 13 Jul, 2020 |          CDN$ 10.99
# 403. The Witcher 3: Wild Hunt - Game of the Year Edition | 30 Aug, 2016 |          CDN$ 69.99
# 404. ARK: Extinction - Expansion Pack | 6 Nov, 2018 |          CDN$ 22.79
# 405. Left 4 Dead Bundle |  |          CDN$ 17.24
# 406. Ravenfield | 18 May, 2017 |          CDN$ 16.99
# 407. Rust - Sunburn Pack | 9 Jul, 2020 |          CDN$ 11.49
# 408. Starbound | 22 Jul, 2016 |          CDN$ 16.99
# 409. Hatsune Miku VR / 初音ミク VR | 8 Mar, 2018 |          CDN$ 28.99
# 410. Expansion - Hearts of Iron IV: Man the Guns | 28 Feb, 2019 |          CDN$ 22.79
# 411. Outlast | 4 Sep, 2013 |          CDN$ 22.79
# 412. Fallout 3: Game of the Year Edition | 17 Dec, 2009 |          CDN$ 21.99
# 413. LEGO® MARVEL's Avengers | 26 Jan, 2016 |          CDN$ 29.99CDN$ 7.49
# 414. DARK SOULS™: REMASTERED | 23 May, 2018 |          CDN$ 49.99
# 415. RPG Maker MZ Bundle S |  |          CDN$ 214.74CDN$ 174.71
# 416. Beasts of Bermuda | 21 Dec, 2018 |          CDN$ 22.79
# 417. Battlefield: Bad Company™ 2 | 2 Mar, 2010 |          CDN$ 26.99CDN$ 6.74
# 418. The Borderlands Bundle |  |          CDN$ 361.46CDN$ 68.83
# 419. Monster Prom: First Crush Bundle |  |          CDN$ 17.16
# 420. The Witcher 2: Assassins of Kings Enhanced Edition | 16 Apr, 2012 |          CDN$ 21.99
# 421. BIGFOOT | Jan 2017 |          CDN$ 18.49
# 422. Street Fighter V | 16 Feb, 2016 |          CDN$ 24.99CDN$ 9.99
# 423. Victory Road | 10 Mar, 2020 |          CDN$ 22.79
# 424. Puyo Puyo™Tetris® | 27 Feb, 2018 |          CDN$ 24.99
# 425. Heat | 25 Jun, 2020 |          CDN$ 22.79
# 426. Garden Flipper | 16 May, 2019 |          CDN$ 17.49
# 427. Volcanoids | 29 Jan, 2019 |          CDN$ 22.79
# 428. STAR WARS™: Squadrons | 2 Oct, 2020 |          CDN$ 54.99
# 429. SYNTHETIK: Legion Rising | 15 Mar, 2018 |          CDN$ 22.99
# 430. Mark of the Ninja: Remastered | 9 Oct, 2018 |          CDN$ 22.79
# 431. PAYDAY 2: San Martín Bank Heist | 27 Feb, 2020 |          CDN$ 7.99CDN$ 5.99
# 432. DYNASTY WARRIORS 8: Xtreme Legends Complete Edition | 13 May, 2014 |          CDN$ 54.99CDN$ 21.99
# 433. Eastside Hockey Manager | 1 Dec, 2015 |          CDN$ 21.99
# 434. Tower Unite | 8 Apr, 2016 |          CDN$ 22.79
# 435. Cooking Simulator | 6 Jun, 2019 |          CDN$ 22.79CDN$ 14.81
# 436. Age of Empires II: Definitive Edition + Age of Empires II (2013) |  |          CDN$ 32.98
# 437. Call of Duty®: Black Ops III | 6 Nov, 2015 |          CDN$ 79.99
# 438. Galaxy Trucker: Extended Edition | 7 Mar, 2019 |          CDN$ 11.49
# 439. Police Simulator: Patrol Duty | 18 Jun, 2019 |          CDN$ 22.89
# 440. Sid Meier's Civilization® IV | 25 Oct, 2006 |          CDN$ 21.99
# 441. Secret Neighbor | 24 Oct, 2019 |          CDN$ 22.79
# 442. BioShock™ 2 Remastered | 15 Sep, 2016 |          CDN$ 21.99
# 443. Need for Speed™ Heat | 4 Jun, 2020 |          CDN$ 89.99
# 444. CrossCode | 21 Sep, 2018 |          CDN$ 21.99CDN$ 17.59
# 445. LEGO® Indiana Jones™: The Original Adventures | 8 Jul, 2009 |          CDN$ 22.79
# 446. Kingdom Come: Deliverance - Royal DLC Package | 28 May, 2019 |          CDN$ 22.79
# 447. Downward Spiral: Horus Station | 31 May, 2018 |          CDN$ 22.79
# 448. Cities: Skylines - Mass Transit | 18 May, 2017 |          CDN$ 13.99
# 449. Portal Knights | 18 May, 2017 |          CDN$ 21.99CDN$ 8.79
# 450. Autonauts | 17 Oct, 2019 |          CDN$ 22.79
# 451. RISK: Global Domination - Premium Mode | 19 Feb, 2020 |          CDN$ 14.49
# 452. Jenny LeClue - Detectivu | 19 Sep, 2019 |          CDN$ 24.99CDN$ 18.74
# 453. Democracy 3 | 14 Oct, 2013 |          CDN$ 27.99
# 454. Portal 2 | 19 Apr, 2011 |          CDN$ 11.49
# 455. Danganronpa 1/2/V3 |  |          CDN$ 67.10
# 456. Golf With Your Friends | 19 May, 2020 |          CDN$ 17.49
# 457. Insurgency: Sandstorm | 12 Dec, 2018 |          CDN$ 37.49
# 458. Zero Escape Trilogy |  |          CDN$ 45.42
# 459. Port Royale 3 Gold | 30 Aug, 2013 |          CDN$ 21.99
# 460. Counter-Strike: Source | 1 Nov, 2004 |          CDN$ 11.49
# 461. Destiny 2: Forsaken | 1 Oct, 2019 |          CDN$ 34.99
# 462. SEGA Mega Drive and Genesis Classics |  |          CDN$ 47.12
# 463. WRC 7 FIA World Rally Championship | 15 Sep, 2017 |          CDN$ 43.99CDN$ 6.59
# 464. Ys Origin | 31 May, 2012 |          CDN$ 21.99
# 465. Total War: WARHAMMER - Call of the Beastmen | 28 Jul, 2016 |          CDN$ 21.99
# 466. Sid Meier's Civilization V: Complete |  |          CDN$ 54.41
# 467. Danganronpa V3: Killing Harmony | 26 Sep, 2017 |          CDN$ 45.49
# 468. Travellers Rest | 28 Jul, 2020 |          CDN$ 17.49
# 469. Stellaris: Lithoids Species Pack | 24 Oct, 2019 |          CDN$ 8.99
# 470. Company of Heroes |  |          CDN$ 21.99
# 471. Captain Tsubasa: Rise of New Champions | 27 Aug, 2020 |          CDN$ 79.99
# 472. Don't Starve Together | 21 Apr, 2016 |          CDN$ 16.99
# 473. Expansion - Europa Universalis IV: Art of War | 30 Oct, 2014 |          CDN$ 21.99
# 474. Deep Rock Galactic - MegaCorp Pack | 13 May, 2020 |          CDN$ 8.99
# 475. PC Building Simulator - Esports Expansion | 4 Aug, 2020 |          CDN$ 14.49
# 476. Deep Rock Galactic - Supporter Upgrade | 28 Feb, 2018 |          CDN$ 17.49
# 477. Cows VS Vikings | 6 Dec, 2018 |          CDN$ 10.29
# 478. Landlord's Super | 30 Apr, 2020 |          CDN$ 22.79CDN$ 20.51
# 479. Town of Salem - Game + Coven + Soundtrack |  |          CDN$ 10.99
# 480. Paint the Town Red | 13 Oct, 2015 |          CDN$ 17.49
# 481. Townscaper | 30 Jun, 2020 |          CDN$ 6.69
# 482. RPG Maker MZ | 20 Aug, 2020 |          CDN$ 91.99CDN$ 82.79
# 483. American Truck Simulator - Washington | 11 Jun, 2019 |          CDN$ 12.99
# 484. Street Fighter V - Champion Edition |  |          CDN$ 39.99CDN$ 29.98
# 485. Battlefield 3™ | 11 Jun, 2020 |          CDN$ 54.99CDN$ 10.99
# 486. Barotrauma | 5 Jun, 2019 |          CDN$ 38.99
# 487. Deep Rock Galactic - Dark Future Pack | 13 May, 2020 |          CDN$ 8.99
# 488. Mist Survival | 15 Aug, 2018 |          CDN$ 12.49
# 489. Rebel Inc: Escalation | 15 Oct, 2019 |          CDN$ 17.49
# 490. Dead by Daylight - Silent Hill Edition |  |          CDN$ 55.38
# 491. Barony | 23 Jun, 2015 |          CDN$ 17.49
# 492. NEKOPARA Vol. 3 | 25 May, 2017 |          CDN$ 10.99
# 493. The LEGO® NINJAGO® Movie Video Game | 22 Sep, 2017 |          CDN$ 29.99CDN$ 14.99
# 494. Among Us - Hamster Pet Bundle | 7 Jun, 2019 |          CDN$ 3.39
# 495. Expansion - Europa Universalis IV: The Cossacks | 1 Dec, 2015 |          CDN$ 21.99
# 496. Battle Brothers - Support the Developers & Southern Banner | 13 Aug, 2020 |          CDN$ 11.49
# 497. Wizard of Legend | 15 May, 2018 |          CDN$ 18.49
# 498. Expansion - Europa Universalis IV: Rights of Man | 11 Oct, 2016 |          CDN$ 21.99
# 499. Remnant: From the Ashes - Swamps of Corsus | 28 Apr, 2020 |          CDN$ 11.49
# 500. Kingdom Under Fire: The Crusaders | 28 Feb, 2020 |          CDN$ 19.99CDN$ 11.99
# 501. Mutazione | 19 Sep, 2019 |          CDN$ 22.79CDN$ 15.95
# 502. Football, Tactics & Glory | 1 Jun, 2018 |          CDN$ 28.99CDN$ 17.39
# 503. Kingdom Rush Origins | 17 Oct, 2018 |          CDN$ 17.49
# 504. The Elder Scrolls III: Morrowind® Game of the Year Edition | 16 Jun, 2009 |          CDN$ 19.99
# 505. The Sims™ 4 Deluxe + Cats & Dogs Bundle |  |          CDN$ 67.30
# 506. LEGO® City Undercover | 4 Apr, 2017 |          CDN$ 29.99CDN$ 7.49
# 507. PAYDAY 2: Border Crossing Heist | 7 Nov, 2019 |          CDN$ 7.99CDN$ 5.99
# 508. ARK: Survival Evolved Explorer's Edition |  |          CDN$ 104.48
# 509. Overcooked! 2 - Season Pass | 18 Apr, 2019 |          CDN$ 22.79
# 510. Forts | 19 Apr, 2017 |          CDN$ 16.99
# 511. realMyst: Masterpiece Edition | 5 Feb, 2014 |          CDN$ 19.99
# 512. Meteorfall: Krumit's Tale | 23 Jul, 2020 |          CDN$ 17.49
# 513. Amazing Frog? | 21 Nov, 2014 |          CDN$ 18.49
# 514. Squally | 6 Nov, 2018 |          CDN$ 28.99
# 515. Planet Zoo: South America Pack  | 7 Apr, 2020 |          CDN$ 11.49
# 516. Subsistence | 25 Oct, 2016 |          CDN$ 14.99
# 517. Bloodstained: Curse of the Moon 2 | 10 Jul, 2020 |          CDN$ 18.89
# 518. BONEWORKS | 10 Dec, 2019 |          CDN$ 33.99
# 519. MXGP 2019 - The Official Motocross Videogame | 27 Aug, 2019 |          CDN$ 56.99CDN$ 14.24
# 520. Arma 3 | 12 Sep, 2013 |          CDN$ 43.99
# 521. Dawn of Man | 1 Mar, 2019 |          CDN$ 28.99
# 522. People Playground | 23 Jul, 2019 |          CDN$ 11.49
# 523. Endless Legend™ - Inferno | 2 Aug, 2018 |          CDN$ 15.99
# 524. Endless Legend™ - Symbiosis | 24 Jan, 2019 |          CDN$ 15.99
# 525. Planet Zoo: Deluxe Upgrade Pack | 5 Nov, 2019 |          CDN$ 13.49
# 526. Hashiriya Drifter - Online Multiplayer Drift Game | 10 Jul, 2020 |          CDN$ 17.49
# 527. Total War: WARHAMMER II - The Shadow & The Blade | 12 Dec, 2019 |          CDN$ 10.49
# 528. Papers, Please | 8 Aug, 2013 |          CDN$ 10.99CDN$ 5.49
# 529. Prison Architect - Total Lockdown |  |          CDN$ 49.01
# 530. Age of Wonders III - Eternal Lords Expansion | 14 Apr, 2015 |          CDN$ 21.99
# 531. Cuphead | 29 Sep, 2017 |          CDN$ 21.99
# 532. Welcome to the Game II | 3 Apr, 2018 |          CDN$ 12.99
# 533. Kingdom Under Fire: Heroes | 24 Jun, 2020 |          CDN$ 19.99CDN$ 13.99
# 534. Stream Avatars | 26 Jul, 2017 |          CDN$ 16.99
# 535. PAYDAY 2: San Martín Bundle |  |          CDN$ 18.16CDN$ 8.42
# 536. Call of Duty®: Black Ops - Rezurrection Content Pack | 22 Sep, 2011 |          CDN$ 16.99
# 537. Risk of Rain 2 Soundtrack | 11 Aug, 2020 |          CDN$ 7.99
# 538. Hollow Knight - Gods & Nightmares | 9 Aug, 2018 |          CDN$ 5.69CDN$ 2.84
# 539. Disco Elysium | 15 Oct, 2019 |          CDN$ 45.49
# 540. FSX Steam Edition: Air Hauler 2 Add-On | 28 Mar, 2019 |          CDN$ 51.49
# 541. The Witcher® 3: Wild Hunt | 18 May, 2015 |          CDN$ 55.99
# 542. Elmarion: Dragon time | 12 Mar, 2020 |          CDN$ 11.49CDN$ 8.04
# 543. Outer Wilds | 18 Jun, 2020 |          CDN$ 28.99
# 544. For the People | 13 Aug, 2020 |          CDN$ 19.49CDN$ 16.56
# 545. PAYDAY 2: Fugitive Weapon Pack | 30 Jun, 2020 |          CDN$ 3.39CDN$ 3.05
# 546. iRacing | 12 Jan, 2015 |          CDN$ 10.99
# 547. Caves of Qud | 15 Jul, 2015 |          CDN$ 17.49
# 548. iRacing | 12 Jan, 2015 |          CDN$ 10.99
# 549. Dead By Daylight - Silent Hill Chapter | 16 Jun, 2020 |          CDN$ 7.99
# 550. Bloons TD 6 | 17 Dec, 2018 |          CDN$ 11.49
# 551. Assetto Corsa Competizione - Intercontinental GT Pack | 4 Feb, 2020 |          CDN$ 17.49
# 552. Stellaris | 9 May, 2016 |          CDN$ 43.99
# 553. Sin Slayers | 5 Sep, 2019 |          CDN$ 17.49
# 554. DG2: Defense Grid 2 | 23 Sep, 2014 |          CDN$ 17.49
# 555. The Sims™ 4 Cats & Dogs | 18 Jun, 2020 |          CDN$ 51.99
# 556. Mystic Vale | 31 Jan, 2019 |          CDN$ 17.49
# 557. The Curse of Kubel | 24 Jul, 2020 |          CDN$ 17.49
# 558. Fishing Planet: Rainforest Journey Pack | 8 May, 2020 |          CDN$ 28.99
# 559. Feed and Grow: Fish | 8 Jan, 2016 |          CDN$ 16.99
# 560. Scrutinized | 5 Aug, 2020 |          CDN$ 13.49
# 561. Project Winter | 23 May, 2019 |          CDN$ 22.79
# 562. Planet Zoo: Arctic Pack | 17 Dec, 2019 |          CDN$ 11.49
# 563. Darkwood | 17 Aug, 2017 |          CDN$ 16.99
# 564. The Warlord package |  |          CDN$ 73.93
# 565. Warhammer® 40,000: Dawn of War® - Game of the Year Edition | 7 Aug, 2007 |          CDN$ 13.99
# 566. Total War: THREE KINGDOMS - Mandate of Heaven | 16 Jan, 2020 |          CDN$ 11.99
# 567. PAYDAY 2: Border Crossing Bundle |  |          CDN$ 14.77CDN$ 8.53
# 568. Mafia | 28 Aug, 2002 |          CDN$ 16.99
# 569. Expansion - Europa Universalis IV: Conquest of Paradise | 14 Jan, 2014 |          CDN$ 16.99
# 570. Sid Meier’s Civilization® VI: Rise and Fall | 7 Feb, 2018 |          CDN$ 32.99
# 571. THE LAST PLAYER:VR Battle Royale | 7 Aug, 2019 |          CDN$ 22.79CDN$ 15.95
# 572. Hollow Knight - Official Soundtrack | 24 Feb, 2017 |          CDN$ 10.99CDN$ 5.49
# 573. ARK: Survival Evolved Season Pass | 1 Sep, 2016 |          CDN$ 49.99
# 574. FSX: Steam Edition + Piper Aztec Twin Pack |  |          CDN$ 34.98
# 575. FSX: Steam Edition + Piper Aztec Twin Pack |  |          CDN$ 34.98
# 576. Expansion - Europa Universalis IV: El Dorado | 26 Feb, 2015 |          CDN$ 16.99
# 577. Generation Zero® | 26 Mar, 2019 |          CDN$ 29.99
# 578. Among Us - Bedcrab Pet Bundle | 7 Jun, 2019 |          CDN$ 3.39
# 579. DCS: F/A-18C Hornet | 1 Jun, 2018 |          CDN$ 112.99
# 580. Sparklite | 14 Nov, 2019 |          CDN$ 28.99CDN$ 14.49
# 581. Ori and the Will of the Wisps | 10 Mar, 2020 |          CDN$ 39.99
# 582. Total War: WARHAMMER II - The Queen & The Crone | 31 May, 2018 |          CDN$ 10.49
# 583. Tropico 6 - Lobbyistico | 9 Jul, 2020 |          CDN$ 11.49
# 584. The Elder Scrolls Online - Newcomer Pack | 20 May, 2019 |          CDN$ 12.99
# 585. Stellaris: Ancient Relics Story Pack | 4 Jun, 2019 |          CDN$ 11.49
# 586. The Elder Scrolls Online - Greymoor | 26 May, 2020 |          CDN$ 54.99
# 587. Warhammer® 40,000: Dawn of War® - Soulstorm | 5 Mar, 2008 |          CDN$ 13.99
# 588. Withstand: Survival | 5 Mar, 2020 |          CDN$ 11.99
# 589. Door Kickers: Action Squad | 10 Sep, 2018 |          CDN$ 15.49
# 590. Hydroneer | 8 May, 2020 |          CDN$ 11.49
# 591. The Jackbox Party Pack 5 | 17 Oct, 2018 |          CDN$ 33.99
# 592. Fishing Planet Anniversary Pack | 25 Aug, 2016 |          CDN$ 22.79CDN$ 15.95
# 593. Space Engineers - Frostbite | 19 Mar, 2020 |          CDN$ 4.65
# 594. TY the Tasmanian Tiger 3 | 17 Dec, 2018 |          CDN$ 17.49
# 595. Warhammer® 40,000: Dawn of War® – Winter Assault | 7 Aug, 2007 |          CDN$ 13.99
# 596. Hunt: Showdown - Legends of the Bayou | 27 Aug, 2019 |          CDN$ 12.49
# 597. UNO | 3 Jan, 2017 |          CDN$ 13.49
# 598. Dead by Daylight - Cursed Legacy Chapter | 3 Dec, 2019 |          CDN$ 7.99
# 599. The Elder Scrolls Online - Greymoor | 26 May, 2020 |          CDN$ 54.99
# 600. Dungeonmans | 9 Dec, 2014 |          CDN$ 16.99
# 601. The Walking Dead Onslaught | 29 Sep, 2020 |          CDN$ 33.99CDN$ 30.59
# 602. Arma 3 Marksmen | 8 Apr, 2015 |          CDN$ 13.49
# 603. Fallout 4 Season Pass | 5 Apr, 2016 |          CDN$ 69.99
# 604. Arma 3 Tanks | 11 Apr, 2018 |          CDN$ 12.99
# 605. Dark Bestiary | 12 Jul, 2020 |          CDN$ 13.49
# 606. RAGE | 4 Oct, 2011 |          CDN$ 12.99
# 607. Expansion - Europa Universalis IV: Mare Nostrum | 5 Apr, 2016 |          CDN$ 16.99
# 608. Left 4 Dead | 17 Nov, 2008 |          CDN$ 11.49
# 609. Wreckfest | 14 Jun, 2018 |          CDN$ 39.99
# 610. Orcs Must Die! Complete Pack | 11 Oct, 2011 |          CDN$ 14.49
# 611. Deus Ex: Mankind Divided™ DLC - Season Pass | 23 Aug, 2016 |          CDN$ 14.99
# 612. Ideology in Friction | 14 Jun, 2019 |          CDN$ 28.99CDN$ 14.49
# 613. Destiny 2: Season of Arrivals Silver Bundle | 9 Jun, 2020 |          CDN$ 18.99
# 614. Getting Over It with Bennett Foddy | 6 Dec, 2017 |          CDN$ 8.99
# 615. Assetto Corsa | 19 Dec, 2014 |          CDN$ 22.79
# 616. Encased: A Sci-Fi Post-Apocalyptic RPG | 26 Sep, 2019 |          CDN$ 33.99CDN$ 27.19
# 617. The Witcher: Enhanced Edition Director's Cut | 16 Sep, 2008 |          CDN$ 10.99
# 618. Pacify | 22 Feb, 2019 |          CDN$ 5.69
# 619. Grim Dawn - Forgotten Gods Expansion | 27 Mar, 2019 |          CDN$ 18.49
# 620. OMSI 2 Add-on Strassenbahn NF6D Essen/Gelsenkirchen | 28 Jul, 2016 |          CDN$ 22.60CDN$ 15.82
# 621. Arma 3 Helicopters | 4 Nov, 2014 |          CDN$ 12.99
# 622. Company of Heroes 2 | 25 Jun, 2013 |          CDN$ 21.99
# 623. Bad North: Jotunn Edition Deluxe Edition Upgrade | 16 Nov, 2018 |          CDN$ 7.99CDN$ 3.99
# 624. Among Us - Stickmin Pet Bundle | 7 Jun, 2019 |          CDN$ 3.39
# 625. Monster Hunter World: Iceborne Digital Deluxe |  |          CDN$ 64.99
# 626. Ancestors Legacy | 22 May, 2018 |          CDN$ 39.99CDN$ 11.99
# 627. Darkest Dungeon®: The Crimson Court | 19 Jun, 2017 |          CDN$ 10.99
# 628. Fallout 4 | 10 Nov, 2015 |          CDN$ 39.99
# 629. Town of Salem | 15 Dec, 2014 |          CDN$ 5.49
# 630. PAYDAY 2: Weapon Color Pack 2 | 30 Jun, 2020 |          CDN$ 3.39CDN$ 3.05
# 631. Risk of Rain | 8 Nov, 2013 |          CDN$ 10.99
# 632. Warhammer: Vermintide 2 - Content Bundle |  |          CDN$ 75.78
# 633. Fallout 4: Game of the Year Edition | 10 Nov, 2015 |          CDN$ 79.99
# 634. Approaching Infinity | 5 Aug, 2020 |          CDN$ 12.49
# 635. Battlefield™ Hardline | 11 Jun, 2020 |          CDN$ 54.99CDN$ 10.99
# 636. Battlefield: Bad Company 2 Vietnam | 18 Dec, 2010 |          CDN$ 19.99CDN$ 6.59
# 637. X-Plane 11 | 30 Mar, 2017 |          CDN$ 72.99
# 638. LEGO® STAR WARS™: The Force Awakens | 28 Jun, 2016 |          CDN$ 29.99CDN$ 7.49
# 639. Deep Rock Galactic - Original Soundtrack Volume I + II | 28 Feb, 2018 |          CDN$ 11.49
# 640. Call of Duty®: Black Ops III - Der Eisendrache Zombies Map | 1 May, 2018 |          CDN$ 9.99
# 641. Merchant of the Skies | 17 Apr, 2020 |          CDN$ 17.49CDN$ 13.11
# 642. Expansion - Crusader Kings II: Sword of Islam | 26 Jun, 2012 |          CDN$ 10.99
# 643. Grim Dawn - Ashes of Malmouth Expansion | 11 Oct, 2017 |          CDN$ 20.49
# 644. Borderlands 3 | 13 Mar, 2020 |          CDN$ 79.99CDN$ 39.99
# 645. Prison Architect - Island Bound | 23 Jun, 2020 |          CDN$ 11.49
# 646. Hearts of Iron IV: Mobilization Pack |  |          CDN$ 105.79
# 647. Street Fighter V - Champion Edition Upgrade Kit |  |          CDN$ 33.49CDN$ 25.11
# 648. Freedom Finger + Aesop Rock Soundtrack |  |          CDN$ 24.68CDN$ 14.86
# 649. Witch Hunt | 3 Sep, 2018 |          CDN$ 11.49
# 650. For Honor - Warmonger Hero | 6 Aug, 2020 |          CDN$ 10.99
# 651. Sid Meier's Pirates! | 25 Oct, 2006 |          CDN$ 10.99
# 652. Beat Saber - Imagine Dragons Music Pack |  |          CDN$ 14.90
# 653. Motorsport Manager - Challenge Pack | 21 Aug, 2017 |          CDN$ 8.79
# 654. Little Witch Nobeta | 24 Jun, 2020 |          CDN$ 11.49
# 655. Drawful 2 | 21 Jun, 2016 |          CDN$ 10.99
# 656. CODE VEIN | 26 Sep, 2019 |          CDN$ 79.99
# 657. LEGO® Marvel™ Super Heroes | 22 Oct, 2013 |          CDN$ 19.99CDN$ 4.99
# 658. Democracy 3 Africa | 12 Apr, 2016 |          CDN$ 16.99
# 659. Space Engineers | 28 Feb, 2019 |          CDN$ 22.79
# 660. 60 Seconds! Reatomized | 25 Jul, 2019 |          CDN$ 10.99
# 661. Trap Legend | 17 Jul, 2020 |          CDN$ 11.49
# 662. Stellaris: Distant Stars Story Pack | 22 May, 2018 |          CDN$ 11.49
# 663. Imperator: Rome - Magna Graecia Content Pack | 31 Mar, 2020 |          CDN$ 8.99
# 664. Portal Bundle |  |          CDN$ 17.24
# 665. theHunter: Call of the Wild™ - Tents & Ground Blinds | 27 Apr, 2017 |          CDN$ 4.99
# 666. Age of Wonders III - Golden Realms Expansion | 18 Sep, 2014 |          CDN$ 12.99
# 667. SWORD ART ONLINE Alicization Lycoris | 9 Jul, 2020 |          CDN$ 79.99
# 668. Frostpunk: The Rifts | 27 Aug, 2019 |          CDN$ 5.69
# 669. Warhammer 40,000: Gladius Complete Edition |  |          CDN$ 101.10
# 670. Railway Empire - Complete Collection |  |          CDN$ 44.85
# 671. Space Engineers Deluxe | 4 Jan, 2017 |          CDN$ 8.99
# 672. The Flipper Bundle |  |          CDN$ 46.59
# 673. Brawlhalla - Summer Championship 2020 Pack | 13 Jul, 2020 |          CDN$ 10.29
# 674. Unrailed! | 9 Sep, 2019 |          CDN$ 22.99CDN$ 13.33
# 675. Core Awaken ~The Yuka~ | 10 Jul, 2018 |          CDN$ 11.49
# 676. Expansion - Crusader Kings II: The Republic | 15 Jan, 2013 |          CDN$ 10.99
# 677. Dragon Age: Origins - Ultimate Edition | 26 Oct, 2010 |          CDN$ 39.99
# 678. Assetto Corsa Ultimate Edition |  |          CDN$ 45.53
# 679. Magicka | 25 Jan, 2011 |          CDN$ 10.99
# 680. Destiny 2: Beyond Light + Season | 10 Nov, 2020 |          CDN$ 62.99
# 681. Warhammer: Vermintide 2 - Grail Knight Bundle |  |          CDN$ 12.49
# 682. Psychonauts | 11 Oct, 2006 |          CDN$ 10.99
# 683. Mafia Trilogy | 19 May, 2020 |          CDN$ 79.99
# 684. Resident Evil 3 | 2 Apr, 2020 |          CDN$ 79.99
# 685. XCOM® 2 Collection |  |          CDN$ 128.59
# 686. The Gardens Between | 20 Sep, 2018 |          CDN$ 22.79CDN$ 11.39
# 687. Princess Project | 30 Aug, 2019 |          CDN$ 17.49CDN$ 11.36
# 688. Conan Exiles | 8 May, 2018 |          CDN$ 49.99
# 689. Danganronpa: Trigger Happy Havoc | 18 Feb, 2016 |          CDN$ 21.99
# 690. The Jackbox Party Trilogy 2.0 |  |          CDN$ 76.77
# 691. LEGO® Batman™: The Videogame | 10 Oct, 2008 |          CDN$ 19.99CDN$ 4.99
# 692. SPORE™ | 19 Dec, 2008 |          CDN$ 26.99
# 693. Lab 7: Cold Nights | 6 May, 2020 |          CDN$ 12.49
# 694. VTOL VR | 3 Aug, 2020 |          CDN$ 32.99
# 695. More Spore |  |          CDN$ 54.24
# 696. Necromunda: Underhive Wars | 8 Sep, 2020 |          CDN$ 54.99CDN$ 43.99
# 697. The Isle | 1 Dec, 2015 |          CDN$ 21.99
# 698. The Jackbox Party Pack 2 | 13 Oct, 2015 |          CDN$ 27.99
# 699. Max Payne | 4 Jan, 2008 |          CDN$ 10.99
# 700. Atari Vault | 24 Mar, 2016 |          CDN$ 10.99
# 701. Domina | 3 Apr, 2017 |          CDN$ 10.99
# 702. DOOM Eternal | 20 Mar, 2020 |          CDN$ 79.99
# 703. LEGO® Jurassic World | 12 Jun, 2015 |          CDN$ 29.99CDN$ 7.49
# 704. Holdfast: Nations At War - Collectors Edition |  |          CDN$ 37.32
# 705. The Yakuza Bundle |  |          CDN$ 89.97
# 706. SpongeBob SquarePants: Battle for Bikini Bottom - Rehydrated | 23 Jun, 2020 |          CDN$ 29.99
# 707. PAYDAY 2: Tailor Pack 2 | 27 Feb, 2020 |          CDN$ 3.39CDN$ 2.54
# 708. ATLAS | 22 Dec, 2018 |          CDN$ 33.99
# 709. Metro Exodus | 15 Feb, 2020 |          CDN$ 49.99
# 710. Keep Talking and Nobody Explodes | 8 Oct, 2015 |          CDN$ 16.99
# ...
# 5455. Yu-Gi-Oh! Classic: The Dueling Monkey | 28 Mar, 2017 |          CDN$ 2.19
# 5456. Cyberemo 2007 | 22 Jun, 2020 |          CDN$ 1.19CDN$ 0.59
# 5457. Yu-Gi-Oh! Classic: Dungeon Dice Monsters Part 4 (Endgame) | 28 Mar, 2017 |          CDN$ 2.19
# 5458. Mini Words - minimalist puzzle | 24 Oct, 2019 |          CDN$ 2.29
# 5459. DETOUR | 16 May, 2011 |          CDN$ 1.00
# 5460. Yu-Gi-Oh! Classic: Champion vs. Creator Part 2 | 28 Mar, 2017 |          CDN$ 2.19
# 5461. The Deer | 3 Dec, 2015 |          CDN$ 0.89CDN$ 0.59
# 5462. Yu-Gi-Oh! Classic: Ties of Friendship | 28 Mar, 2017 |          CDN$ 2.19
# 5463. Yu-Gi-Oh! Classic: Dungeon Dice Monsters Part 1 | 28 Mar, 2017 |          CDN$ 2.19
# 5464. Streets of Rage 2 | 26 Jan, 2011 |          CDN$ 1.19
# 5465. Yu-Gi-Oh! Classic: Everything's Relative | 28 Mar, 2017 |          CDN$ 2.19
# 5466. Yu-Gi-Oh! Classic: Face Off Part 2 | 28 Mar, 2017 |          CDN$ 2.19
# 5467. Sea Legends: Phantasmal Light Collector's Edition | 17 Sep, 2014 |          CDN$ 5.49CDN$ 1.09
# 5468. Yu-Gi-Oh! Classic: Yugi vs. Pegasus Match of the Millennium Part 4 | 28 Mar, 2017 |          CDN$ 2.19
# 5469. Yu-Gi-Oh! Classic: Into the Hornet's Nest | 28 Mar, 2017 |          CDN$ 2.19
# 5470. Yu-Gi-Oh! Classic: Yugi vs. Pegasus Match of the Millennium Part 1 | 28 Mar, 2017 |          CDN$ 2.19
# 5471. Yu-Gi-Oh! Classic: The Scars of Defeat | 28 Mar, 2017 |          CDN$ 2.19
# 5472. Hentai Shooter 3D - Art Collection | 3 Sep, 2018 |          CDN$ 3.39CDN$ 0.61
# 5473. Yu-Gi-Oh! Classic: Keith's Machination Part 1 | 28 Mar, 2017 |          CDN$ 2.19
# 5474. Yu-Gi-Oh! Classic: Trial By Red Eyes | 28 Mar, 2017 |          CDN$ 2.19
# 5475. Yu-Gi-Oh! Classic: Double Trouble Duel Part 2 | 28 Mar, 2017 |          CDN$ 2.19
# 5476. Yu-Gi-Oh! Classic: The Night Before | 28 Mar, 2017 |          CDN$ 2.19
# 5477. Yu-Gi-Oh! Classic: The Ultimate Great Moth | 28 Mar, 2017 |          CDN$ 2.19
# 5478. Yu-Gi-Oh! Classic: Legendary Heroes Part 1 | 28 Mar, 2017 |          CDN$ 2.19
# 5479. Yu-Gi-Oh! Classic: Duel with A Ghoul | 28 Mar, 2017 |          CDN$ 2.19
# 5480. Yu-Gi-Oh! Classic: Face Off Part 3 | 28 Mar, 2017 |          CDN$ 2.19
# 5481. Coloring Pixels - Marine Life Pack | 7 Aug, 2020 |          CDN$ 1.19
# 5482. Yu-Gi-Oh! Classic: The Heart of The Cards | 28 Mar, 2017 |          CDN$ 2.19
# 5483. Yu-Gi-Oh! Classic: Yugi vs. Pegasus Match of the Millennium Part 5 | 28 Mar, 2017 |          CDN$ 2.19
# 5484. Yu-Gi-Oh! Classic: Evil Spirit of The Ring | 28 Mar, 2017 |          CDN$ 2.19
# 5485. En Tactico | 10 Apr, 2018 |          CDN$ 2.29CDN$ 0.59
# 5486. Yu-Gi-Oh! Classic: Dungeon Dice Monsters Part 2 | 28 Mar, 2017 |          CDN$ 2.19
# 5487. Yu-Gi-Oh! Classic: Yugi vs. Pegasus Match of the Millennium Part 2 | 28 Mar, 2017 |          CDN$ 2.19
# 5488. The Dream Machine: Chapter 6 | 11 May, 2017 |          CDN$ 5.49CDN$ 1.37
# 5489. Yu-Gi-Oh! Classic: Arena of Lost Souls Part 1 | 28 Mar, 2017 |          CDN$ 2.19
# 5490. Yu-Gi-Oh! Classic: Keith's Machination Part 2 | 28 Mar, 2017 |          CDN$ 2.19
# 5491. ILLUSION | 9 May, 2018 |          CDN$ 2.29CDN$ 0.59
# 5492. The Dream Machine: Chapter 4 | 5 Aug, 2013 |          CDN$ 5.49CDN$ 1.37
# 5493. SALVATOR | 3 May, 2018 |          CDN$ 1.19CDN$ 0.59
# 5494. IMM Defense | 22 Feb, 2018 |          CDN$ 1.19CDN$ 0.59
# 5495. The Dream Machine: Chapter 3 | 11 May, 2012 |          CDN$ 5.49CDN$ 1.37
# 5496. Adventures of Mike | 24 May, 2018 |          CDN$ 1.19CDN$ 0.59
# 5497. Grave Keeper | 29 Mar, 2019 |          CDN$ 11.49CDN$ 1.14
# 5498. The Metronomicon - Chiptune Challenge Pack 1 | 6 Oct, 2016 |          CDN$ 2.19CDN$ 0.65
# 5499. Clash Force | 25 Oct, 2017 |          CDN$ 5.69CDN$ 1.13
# 5500. Bouncy Bob: Episode 2 | 30 Oct, 2019 |          CDN$ 5.69CDN$ 0.62
# 5501. The Metronomicon - Indie Game Challenge Pack 1 | 13 Oct, 2016 |          CDN$ 2.19CDN$ 0.65
# 5502. 100% Orange Juice - Acceleration Pack | 17 Oct, 2016 |          CDN$ 2.29
# 5503. The Metronomicon - Chiptune Challenge Pack 2 | 20 Oct, 2016 |          CDN$ 2.19CDN$ 0.65
# 5504. Zaccaria Pinball - Earth Wind Fire 2017 Table | 29 May, 2017 |          CDN$ 3.29
# 5505. My Name is Mayo | 15 Feb, 2016 |          CDN$ 1.09
# 5506. Liquid Pinball | 24 Nov, 2016 |          CDN$ 1.09CDN$ 0.59
# 5507. Soldiers: Heroes of World War II | 3 Jul, 2014 |          CDN$ 5.49CDN$ 1.09
# 5508. The Metronomicon - J-Punch Challenge Pack | 29 Nov, 2016 |          CDN$ 2.19CDN$ 0.65
# 5509. Helicopter Simulator 2014: Search and Rescue | 28 Feb, 2014 |          CDN$ 10.99CDN$ 1.09
# 5510. Suits: A Business RPG | 5 Jan, 2016 |          CDN$ 1.09
# 5511. Stronghold Crusader 2: Freedom Fighters mini-campaign |  |          CDN$ 1.09
# 5512. Ultimate Spinner Simulator - Unstress Yourself | 27 Oct, 2017 |          CDN$ 1.19CDN$ 0.59
# 5513. Stronghold Crusader 2: Delivering Justice mini-campaign | 17 Dec, 2015 |          CDN$ 1.09
# 5514. Star Wolves 3: Civil War | 2 Mar, 2010 |          CDN$ 5.49CDN$ 1.09
# 5515. Euro Truck Simulator 2 - Canadian Paint Jobs Pack | 1 Jul, 2014 |          CDN$ 1.09
# 5516. Euro Truck Simulator 2 - Brazilian Paint Jobs Pack | 11 Jun, 2014 |          CDN$ 1.09
# 5517. Jambo | 24 Jan, 2018 |          CDN$ 1.19CDN$ 0.59
# 5518. METAL GEAR SOLID V: THE PHANTOM PAIN - Sneaking Suit (The Boss) | 20 Oct, 2015 |          CDN$ 1.09
# 5519. Survival Space: Unlimited Shooting | 31 Jan, 2018 |          CDN$ 1.19CDN$ 0.59
# 5520. Theatre of War 2: Africa 1943 | 9 Jul, 2010 |          CDN$ 5.49CDN$ 1.09
# 5521. Zaccaria Pinball - Spooky 2017 Table | 22 Aug, 2017 |          CDN$ 3.29
# 5522. Castle Crashers - Blacksmith Pack | 26 Sep, 2012 |          CDN$ 1.09
# 5523. World War I | 9 Apr, 2015 |          CDN$ 5.49CDN$ 1.09
# 5524. All Alone: VR | 8 Mar, 2017 |          CDN$ 4.49
# 5525. Theatre of War 2: Kursk 1943 | 9 Jul, 2010 |          CDN$ 5.49CDN$ 1.09
# 5526. Hotel Dracula | 9 Feb, 2018 |          CDN$ 5.69CDN$ 0.62
# 5527. UNICLR - Additional Londrekia's Color (No.31-40) | 26 Mar, 2020 |          CDN$ 1.19
# 5528. Burn It Down | 3 Aug, 2017 |          CDN$ 1.09
# 5529. The Last Dawn : The first invasion | 7 May, 2018 |          CDN$ 3.39CDN$ 0.61
# 5530. ORION: Prelude | 15 Apr, 2013 |          CDN$ 1.09
# 5531. Battlevoid: Sector Siege OST | 25 Oct, 2017 |          CDN$ 1.99CDN$ 0.59
# 5532. Roulette Simulator 2 | 31 Dec, 2018 |          CDN$ 1.19CDN$ 0.59
# 5533. Men of War™ | 6 May, 2009 |          CDN$ 5.49CDN$ 1.09
# 5534. Isotiles - Isometric Puzzle Game | 16 Jun, 2017 |          CDN$ 2.19
# 5535. Euro Truck Simulator 2 - Italian Paint Jobs Pack | 4 May, 2016 |          CDN$ 1.09
# 5536. LYSER | 6 Jun, 2019 |          CDN$ 1.19
# 5537. Wildlife Park 2 - Fantasy | 17 Jul, 2014 |          CDN$ 1.09
# 5538. Cats are Liquid - A Light in the Shadows | 25 Jul, 2016 |          CDN$ 1.09
# 5539. SpeedRunners - Civil Dispute! Character Pack | 20 Jul, 2018 |          CDN$ 3.39
# 5540. Satellite - OST | 24 Jul, 2018 |          CDN$ 1.19CDN$ 0.65
# 5541. The Metronomicon - The End Records Challenge Pack | 6 Sep, 2017 |          CDN$ 2.19CDN$ 0.65
# 5542. Steamulator 2019 | 30 Jan, 2019 |          CDN$ 1.19CDN$ 0.65
# 5543. Hang The Kings | 25 Oct, 2019 |          CDN$ 1.19
# 5544. Knight Swap | 22 Oct, 2019 |          CDN$ 1.19
# 5545. Sakura Clicker - Hairstyle Pack | 29 Jul, 2015 |          CDN$ 1.09
# 5546. Cube Shifter | 14 Aug, 2020 |          CDN$ 1.19CDN$ 0.95
# 5547. Bronze Age - HD Edition | 25 Sep, 2017 |          CDN$ 3.29CDN$ 0.98
# 5548. Blackout Z: Original Soundtrack | 23 Oct, 2017 |          CDN$ 1.19CDN$ 0.59
# 5549. Risen 3 - Fog Island |  |          CDN$ 5.49CDN$ 1.37
# 5550. Blackout Z: Slaughterhouse Edition | 20 Oct, 2017 |          CDN$ 1.19CDN$ 0.59
# 5551. 100% Orange Juice - Mixed Booster Pack | 9 Mar, 2015 |          CDN$ 2.29
# 5552. Resident Evil 0 "Shadow of Fear" Rebecca T-shirt | 20 Jan, 2016 |          CDN$ 0.99
# 5553. Car Mechanic Simulator 2015 - Car Stripping | 24 Apr, 2017 |          CDN$ 1.09CDN$ 0.59
# 5554. Urizen Shadows of the Cold Deluxe Frosty Edition | 31 Aug, 2015 |          CDN$ 2.29CDN$ 1.03
# 5555. Seek Girl - Charming girl | 30 Apr, 2019 |          CDN$ 1.19
# 5556. Seek Girl Ⅱ | 30 Sep, 2019 |          CDN$ 1.19
# 5557. Taboos: Cracks | 2 May, 2019 |          CDN$ 1.19
# 5558. Seek Girl | 14 Mar, 2019 |          CDN$ 1.19
# 5559. Seek Girl Ⅲ | 6 Dec, 2019 |          CDN$ 1.19
# 5560. Hero Barrier | 28 Feb, 2017 |          CDN$ 4.49CDN$ 0.89
# 5561. Perimeter | 3 Apr, 2014 |          CDN$ 4.49CDN$ 0.89
# 5562. Click Legends | 29 May, 2019 |          CDN$ 3.39CDN$ 1.01
# 5563. Whispering Willows - Art Book, Soundtrack, and Wallpaper | 9 Jul, 2014 |          CDN$ 5.49CDN$ 1.09
# 5564. VITATIO | 28 Jul, 2017 |          CDN$ 2.19CDN$ 0.59
# 5565. Godly Corp | 13 Dec, 2018 |          CDN$ 8.99CDN$ 0.89
# 5566. NABOKI | 12 Nov, 2019 |          CDN$ 1.19
# 5567. Caveblazers Soundtrack | 24 May, 2017 |          CDN$ 2.19CDN$ 0.59
# 5568. Blood Code OST | 3 Dec, 2015 |          CDN$ 2.29CDN$ 1.14
# 5569. Jellyfish | 15 Sep, 2017 |          CDN$ 1.19CDN$ 0.59
# 5570. Titanic Package Bundle |  |          CDN$ 22.78
# 5571. Turn on the light | 7 Jul, 2020 |          CDN$ 1.19CDN$ 0.59
# 5572. Farm Expert 2017 | 1 Sep, 2016 |          CDN$ 21.99CDN$ 2.19
# 5573. Nonogram - The Greatest Painter | 22 Mar, 2018 |          CDN$ 3.39
# 5574. SpeedRunners Deluxe Pack |  |          CDN$ 22.92
# 5575. Daylife in Japan - Pixel Art Jigsaw Puzzle | 26 Oct, 2019 |          CDN$ 2.29
# 5576. The Escapists - Fhurst Peak Correctional Facility | 13 Feb, 2015 |          CDN$ 1.09
# 5577. [Platypus Comic Strips+] To the Moon, too! | 27 Nov, 2015 |          CDN$ 1.09
# 5578. Call of Duty® Franchise Collection |  |          CDN$ 1,139.45
# 5579. Premier Buggy Racing Tour | 10 Oct, 2017 |          CDN$ 1.19CDN$ 0.59
# 5580. Fallen Cube | 14 Jul, 2017 |          CDN$ 1.19CDN$ 0.59
# 5581. Microcosmum: survival of cells - Colors for organisms | 22 Jan, 2016 |          CDN$ 1.09
# 5582. Microcosmum: survival of cells - Random levels | 20 Oct, 2015 |          CDN$ 2.18CDN$ 1.09
# 5583. I Can't Believe It's Not Gambling | 11 Dec, 2017 |          CDN$ 1.19
# 5584. KIDS + PLUG & PLAY |  |          CDN$ 5.68
# 5585. Risen 2: Dark Waters - A Pirate's Clothes DLC | 26 Apr, 2012 |          CDN$ 2.19CDN$ 1.09
# 5586. Runes | 24 Nov, 2016 |          CDN$ 1.09CDN$ 0.59
# 5587. Horse Racing Rally | 19 Mar, 2020 |          CDN$ 2.29CDN$ 0.87
# 5588. Car Mechanic Simulator 2015 - Trader Pack | 3 Jul, 2015 |          CDN$ 4.49CDN$ 0.67
# 5589. The Way | 20 May, 2016 |          CDN$ 16.99CDN$ 1.69
# 5590. Heroes Rise: The Prodigy - Perfect Legend Guide | 17 Jun, 2014 |          CDN$ 1.19
# 5591. 2 Ninjas 1 Cup | 3 Feb, 2017 |          CDN$ 1.19CDN$ 0.83
# 5592. Risen 3 - Adventure Garb |  |          CDN$ 2.19CDN$ 1.09
# 5593. oO | 6 Jul, 2015 |          CDN$ 1.09
# 5594. Kombine | 14 Oct, 2016 |          CDN$ 1.09CDN$ 0.59
# 5595. Ships 2017 | 19 Oct, 2016 |          CDN$ 16.99CDN$ 1.69
# 5596. Spintires - Chernobyl® Bundle |  |          CDN$ 18.05
# 5597. Never Split the Party: Fellowship Unlock | 14 Sep, 2018 |          CDN$ 17.49
# 5598. Lines Infinite | 24 Nov, 2017 |          CDN$ 1.19
# 5599. Marble Trap | 2 Sep, 2019 |          CDN$ 1.19CDN$ 0.71
# 5600. Marble Trap | 2 Sep, 2019 |          CDN$ 1.19CDN$ 0.71
# 5601. A.I.M.2 Clan Wars | 22 May, 2014 |          CDN$ 3.29CDN$ 0.65
# 5602. Ascension to the Throne | 23 Apr, 2014 |          CDN$ 3.29CDN$ 0.65
# 5603. CATGIRL LOVER 2 | 16 Oct, 2019 |          CDN$ 2.29CDN$ 0.59
# 5604. UBERMOSH Vol.7 | 30 Apr, 2019 |          CDN$ 5.69CDN$ 0.62
# 5605. Car Mechanic Simulator 2015 - Visual Tuning | 20 May, 2015 |          CDN$ 2.19CDN$ 0.59
# 5606. El Matador | 3 Apr, 2014 |          CDN$ 4.49CDN$ 0.67
# 5607. How Buddy’s parents met - jigsaw puzzle | 14 Feb, 2020 |          CDN$ 2.29
# 5608. Draw The Way | 19 Nov, 2018 |          CDN$ 6.69CDN$ 0.66
# 5609. Dungeons 3 - Complete Collection |  |          CDN$ 45.65
# 5610. Elemental Girls | 15 May, 2019 |          CDN$ 1.19CDN$ 0.59
# 5611. Sixtieth Kilometer | 25 Aug, 2016 |          CDN$ 1.00CDN$ 0.59
# 5612. Magicolors | 14 Dec, 2019 |          CDN$ 2.29
# 5613. Sudoku Universe / 数独宇宙 | 18 Dec, 2017 |          CDN$ 2.29
# 5614. Impossible Quest | 3 Jun, 2016 |          CDN$ 2.19CDN$ 0.59
# 5615. keyg | 13 Dec, 2018 |          CDN$ 5.69CDN$ 0.62
# 5616. Season Up | 6 Apr, 2018 |          CDN$ 2.29CDN$ 0.59
# 5617. Dual Snake | 30 Jan, 2018 |          CDN$ 4.65CDN$ 0.60
# 5618. Beyond the Wall | 8 Aug, 2017 |          CDN$ 3.39CDN$ 0.61
# 5619. ORB | 13 Mar, 2014 |          CDN$ 5.49CDN$ 0.60
# 5620. Automobilista Ultimate Edition |  |          CDN$ 34.48
# 5621. Zombies on a Plane | 25 Mar, 2016 |          CDN$ 5.49CDN$ 0.60
# 5622. Trip to Vinelands | 21 Oct, 2016 |          CDN$ 1.09CDN$ 0.59
# 5623. aMAZE | 14 Mar, 2017 |          CDN$ 1.09CDN$ 0.59
# 5624. Ninja Stealth | 29 Sep, 2016 |          CDN$ 1.19CDN$ 0.59
# 5625. Car Mechanic Manager | 23 Sep, 2015 |          CDN$ 5.49CDN$ 0.60
# 5626. Kagura Bundle |  |          CDN$ 780.56CDN$ 456.42
# 5627. Lamp Head | 1 Jun, 2017 |          CDN$ 1.19CDN$ 0.59
# 5628. Druid | 17 Jan, 2017 |          CDN$ 1.19CDN$ 0.59
# 5629. Plankton | 27 Oct, 2016 |          CDN$ 2.19CDN$ 0.59
# 5630. Devious Dungeon | 16 Aug, 2019 |          CDN$ 5.99
# 5631. Professor Madhouse | 4 Jun, 2018 |          CDN$ 2.29CDN$ 0.59
# 5632. Incandescent | 30 Jun, 2015 |          CDN$ 1.19CDN$ 0.59
# 5633. Virus Crashers | 21 Feb, 2017 |          CDN$ 1.09CDN$ 0.59
# 5634. UBERMOSH | 13 Aug, 2015 |          CDN$ 1.09CDN$ 0.59
# 5635. Battlevoid: Harbinger OST | 24 Feb, 2016 |          CDN$ 2.19CDN$ 0.59
# 5636. UBERMOSH:WRAITH | 29 Jan, 2017 |          CDN$ 1.09CDN$ 0.59
# 5637. Blood Code Costume Pack | 23 Nov, 2016 |          CDN$ 1.19CDN$ 0.59
# 5638. TTV2 | 11 Sep, 2017 |          CDN$ 1.09CDN$ 0.59
# 5639. Tom Clancy's Rainbow Six® Siege - Amethyst Weapon Skin | 8 Mar, 2016 |          CDN$ 3.99
# 5640. TOTOBALL | 11 Sep, 2017 |          CDN$ 1.19CDN$ 0.59
# 5641. Bighead Runner | 7 Jun, 2018 |          CDN$ 1.19CDN$ 0.59
# 5642. Golden Axe™ | 1 Jun, 2010 |          CDN$ 1.19
# 5643. Clicker: Glad Valakas | 26 Nov, 2018 |          CDN$ 2.29CDN$ 0.59
# 5644. Football Russian 20!8 | 13 Feb, 2018 |          CDN$ 2.29CDN$ 0.59
# 5645. UBERMOSH Vol.3 | 15 Aug, 2016 |          CDN$ 1.09CDN$ 0.59
# 5646. LineWay | 20 Jun, 2017 |          CDN$ 1.19
# 5647. Kabukicho Story | 1 Aug, 2020 |          CDN$ 1.19CDN$ 0.59
# 5648. Endica VII The Dream King | 13 Jan, 2016 |          CDN$ 1.19CDN$ 0.59
# 5649. Blast-off | 22 Jan, 2018 |          CDN$ 1.19
# 5650. Tom Clancy's Rainbow Six® Siege - Platinum Weapon Skin | 23 Feb, 2016 |          CDN$ 3.99
# 5651. Tom Clancy's Rainbow Six® Siege - Topaz Weapon Skin | 12 Apr, 2016 |          CDN$ 3.99
# 5652. Unlock The King | 20 Nov, 2019 |          CDN$ 1.19
# 5653. Sam & Max: The Devil’s Playhouse  | 23 May, 2010 |          CDN$ 32.99
# 5654. Colorgrid | 21 Nov, 2019 |          CDN$ 1.19
# 5655. Zen Chess: Mate in One | 10 Apr, 2018 |          CDN$ 1.19
# 5656. King's Bounty: Dark Side Premium Edition Upgrade |  |          CDN$ 2.19CDN$ 0.59
# 5657. Ashi: Lake of Light | 5 Jul, 2018 |          CDN$ 4.65CDN$ 1.11
# 5658. R.B.I. Baseball 20 | 17 Mar, 2020 |          CDN$ 33.99
# 5659. MX vs ATV All Out | 27 Mar, 2018 |          CDN$ 45.49
# 5660. Screeps | 16 Nov, 2016 |          CDN$ 16.99
# 5661. Depth Hunter 2: Deep Dive | 20 Aug, 2014 |          CDN$ 16.99
# 5662. WOUNDED | 28 Feb, 2019 |          CDN$ 7.99
# 5663. Nancy Drew®: Message in a Haunted Mansion | 1 May, 2017 |          CDN$ 11.49
# 5664. Comanche | 12 Mar, 2020 |          CDN$ 19.99
# 5665. What The Box? | 12 Sep, 2016 |          CDN$ 5.99
# 5666. Kio's Adventure | 5 Apr, 2017 |          CDN$ 2.19
# 5667. Star Valor | 13 Jul, 2018 |          CDN$ 17.49CDN$ 7.34
# 5668. Omen Exitio: Plague | 5 Mar, 2018 |          CDN$ 11.49CDN$ 3.44
# 5669. Call of Duty®: Infinite Warfare | 5 Nov, 2016 |          CDN$ 79.99
# 5670. There's Poop In My Soup | 14 Mar, 2016 |          CDN$ 1.09
# 5671. Red Orchestra: Ostfront 41-45 | 14 Mar, 2006 |          CDN$ 5.69
# 5672. Glass Masquerade 2: Illusions | 27 Feb, 2019 |          CDN$ 5.69
# 5673. Tom Clancy's Rainbow Six® Siege - Montagne Bushido Set | 13 Dec, 2016 |          CDN$ 10.99
# 5674. Reflex Arena | 8 Mar, 2017 |          CDN$ 10.99

# %%
# Create a dataframe with all the information
top_sellers_df = pd.DataFrame(top_sellers)
top_sellers_df
# Out:
#                                               game_name  release_date  \
# 0                          Fall Guys: Ultimate Knockout   3 Aug, 2020
# 1                         Fall Guys Collector's Edition
# 2                                     Marvel's Avengers   4 Sep, 2020
# 3                                              Factorio  14 Aug, 2020
# 4                            Microsoft Flight Simulator     8/18/2020
# ...                                                 ...           ...
# 5670                            There's Poop In My Soup  14 Mar, 2016
# 5671                      Red Orchestra: Ostfront 41-45  14 Mar, 2006
# 5672                      Glass Masquerade 2: Illusions  27 Feb, 2019
# 5673  Tom Clancy's Rainbow Six® Siege - Montagne Bus...  13 Dec, 2016
# 5674                                       Reflex Arena   8 Mar, 2017
#
#            price
# 0     CDN$ 22.79
# 1     CDN$ 33.99
# 2     CDN$ 79.99
# 3     CDN$ 34.00
# 4     CDN$ 79.99
# ...          ...
# 5670   CDN$ 1.09
# 5671   CDN$ 5.69
# 5672   CDN$ 5.69
# 5673  CDN$ 10.99
# 5674  CDN$ 10.99
#
# [5675 rows x 3 columns]

# %%
# Save dataframe into csv file for reading in transform stage
top_sellers_df.to_csv("data/Steam_top_sellers.csv")
